# %%
import sys
import os
import numpy as np

SCRIPT_DIR = os.path.dirname(os.path.abspath("..."))
sys.path.append(os.path.dirname(SCRIPT_DIR))

from datasets import load_from_disk
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
    T5ForConditionalGeneration
)

# %% [markdown]
# # Load goldern dataset that is unseen in train

# %%
test_data = load_from_disk("/opt/home/bo_ling/dataset/eats_receipt_gcp_test.hf")
test_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 4
#     })
#     test: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 419
#     })
# })

# %%
test_data['test'][0]
# Out:
# {'input_text': "What are the receipt_number, total_price, and total_tax in 'COUPONS ONLY Albertsons Store 4279 Dir MICHAEL STOCKTON Main:(817) 447-9106 Rx: (817) 447-8060 833 N E Alsbury Blvd Burleson TX 76028 CAT CHOW NATURALS Regular Price 14.49 You Save 0.50- 2 QTY OREO THINS Regular Price You Save GROCERY GROC NONEDIBLE PUFFS 3X PLUS FAM Regular Price You Save TAX **** BALANCE REFRIG/FROZEN CHOBANI YGRT PMGRN Regular Price You Save GEN MERCHANDISE SIG PETROLEUM JELY SCRUB BUBB AEROSOL SPONGE DADDY PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa 10.98 5.49- 7.99 0.50- YOUR SAVINGS 1.59 0.09- Store Savings Total Total Savings Value CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 08:10 4279 53 4 13.99 T YOUR CASHIER TODAY WAS SELF Credit Purchase 02/26/23 08:10 CARD # ************000 REF: 081033408580 AUTH: 00367287 47.31 5.49 S 7.49 T 1.50 S 2.79 X 5.99 T 6.99 T 3.07 47.31 47.31 0.00 8 8853 6.58 6.58 13% 00427905300042302260810 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?",
#  'output_text': 'receipt_number: 00427905300042302260810; total_price: 47.31; total_tax: 3.07'}

# %% [markdown]
# # Load checkpoint at step: 19600 (12% of total data in first epoch)

# %%
local_output_dir="/opt/home/bo_ling/dolly_training/eats_receipt_gcp_t5"
#model, tokenizer = load_model_tokenizer_for_generate(local_output_dir)
import torch
tokenizer = AutoTokenizer.from_pretrained(local_output_dir)
device = "cuda:2" if torch.cuda.is_available() else "cpu"
model = T5ForConditionalGeneration.from_pretrained(local_output_dir, trust_remote_code=True).to(device)
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.

# %%
def generate_transcipt_response(
    input_text: str,
    model: PreTrainedModel,
    tokenizer: PreTrainedTokenizer,
    PAD_TOKEN = "<pad>",
    EOS_TOKEN = "</s>",
    do_sample: bool = True,
    max_new_tokens: int = 768,
    top_p: float = 0.85,
    top_k: int = 0,
    **kwargs,
) -> str:
    input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to(device)

    end_key_token_id = tokenizer.encode(EOS_TOKEN)[0]

    gen_tokens = model.generate(
        input_ids,
        pad_token_id=tokenizer.pad_token_id,
        # Ensure generation stops once it generates "### End"
        eos_token_id=end_key_token_id,
        do_sample=do_sample,
        max_new_tokens=max_new_tokens,
        top_p=top_p,
        top_k=top_k,
        **kwargs,
    )[0].cpu()

    decoded = tokenizer.decode(gen_tokens).strip(PAD_TOKEN).strip(EOS_TOKEN).strip()

    return decoded

# %% [markdown]
# # Print some sample output for human to read

# %%
count = 0
for d in test_data['test']:
    input_text= d["input_text"]
    generated = generate_transcipt_response(input_text, model, tokenizer)
    expected = d['output_text']
    print("="*100)
    print("="*100)
    print("\nINPUT:")
    print(input_text)
    print("\nGENERATED:")
    print(generated)
    print("\nEXPECTED:")
    print(expected)
    count += 1
    if count > 50:
        break
# Out:
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'COUPONS ONLY Albertsons Store 4279 Dir MICHAEL STOCKTON Main:(817) 447-9106 Rx: (817) 447-8060 833 N E Alsbury Blvd Burleson TX 76028 CAT CHOW NATURALS Regular Price 14.49 You Save 0.50- 2 QTY OREO THINS Regular Price You Save GROCERY GROC NONEDIBLE PUFFS 3X PLUS FAM Regular Price You Save TAX **** BALANCE REFRIG/FROZEN CHOBANI YGRT PMGRN Regular Price You Save GEN MERCHANDISE SIG PETROLEUM JELY SCRUB BUBB AEROSOL SPONGE DADDY PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa 10.98 5.49- 7.99 0.50- YOUR SAVINGS 1.59 0.09- Store Savings Total Total Savings Value CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 08:10 4279 53 4 13.99 T YOUR CASHIER TODAY WAS SELF Credit Purchase 02/26/23 08:10 CARD # ************000 REF: 081033408580 AUTH: 00367287 47.31 5.49 S 7.49 T 1.50 S 2.79 X 5.99 T 6.99 T 3.07 47.31 47.31 0.00 8 8853 6.58 6.58 13% 00427905300042302260810 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00427905300042302260810; total_price: 47.31; total_tax: 3.07
#
# EXPECTED:
# receipt_number: 00427905300042302260810; total_price: 47.31; total_tax: 3.07
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'tvormer C SAFEWAY S S. Store 1652 Dir Veronica Ayala Main: (410) 420-2050 Rx: (410) 420-2053 225 Brier Hill Road Bel Air MD 21015 GROCERY 4 QTY COKE DIET Regular Price 59.96 Member Savings 8.00- TAX **** BALANCE PAYMENT AMOUNT Credit Purchase 02/27/23 17:14 CARD # ************000 REF: 741402452380 AUTH: 00100389 AL AID A0000000031010 TVR 0000000000 TSI 0000 Visa CHANGE 6% SALES TAX TOTAL NUMBER OF ITEMS SOLD = 02/27/23 17:14 1652 95 93 YOUR CASHIER TODAY WAS SELF 51.96 B YOUR SAVINGS 3.12 55.08 Member Savings Total Total Savings Value 55.08 55.08 REWARDS AVAILABLE POINTS EARNED TODAY Base Points 51 Total 51 Points Towards Next Reward 13 of 100 0.00 3.12 4 8895 8.00 8.00 13% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY 00165209500932302271714 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00165209500932302271714; total_price: 55.08; total_tax: 3.12
#
# EXPECTED:
# receipt_number: 00165209500932302271714; total_price: 55.08; total_tax: 3.12
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '0505050476 VEEMA 840 072 LOVE MR SAFEWAY S Store 840 Dir Shannon Robbins Main: (719)_282-9066 Rx: (719) 282-9502 8750 N Union Blvd Colorado Springs CO 80920 32/17/2023 C REFRIG/FROZEN COFFEE-MATE HAZELN NSTLE COFFEE MATE MISCELLANEOUS bvlg DSPSBL BAG CHARGE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 17:04 CARD # ************000 REF: 950407478620 AUTH: 00612129 Visa DIZA CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 17:04 840 54 197 6731-0 7.99 S 7.99 S 0.10 0.00 16.08 16.08 t: 1997 16.08 M 0.00 2 YOUR CASHIER TODAY WAS SELF T 00084005401972302271704 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru 8854'?
#
# GENERATED:
# receipt_number: 00084005401972302271704; total_price: 16.08; total_tax: 0.0
#
# EXPECTED:
# receipt_number: ; total_price: 16.08; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY S Store 8 Dir Carl Schulze Main: (303) 771-8707 Rx:(303) 779-5520 7375 E. Arapahoe Rd. Englewood CO 80112 REFRIG/FROZEN 2 QTY INT DEL CR Regular Price 9.58 Member Savings 0.60- TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/28/23 08:39 CARD # ************000 REF: 283907472100 AUTH: 00429770 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/28/23 08:39 8 54 22 8.98 YOUR CASHIER TODAY WAS SELF YOUR SAVINGS Member Savings Total Total Savings Value 8.98 S 0.00 8.98 8.98 0.00 2 8854 0.60 0.60 6% 00000805400222302280839 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00000805400222302280839; total_price: 8.98; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00000805400222302280839; total_price: 8.98; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY S Store 3281 Dir Anjelica Van Main: (510) 523-1804 Rx: (510) 523-1827 2600 Fifth Street ALAMEDA CA 94501 GROCERY NONG SHIM SHIN RAMAC NBC RITZ CRACKERS AC TAO KAE NOI BIG SEAC REFRIG/FROZEN SHOM BRKLY MILK WHL HG 3.99 S PRODUCE UUR 110 CRAISINS ODS2 3.99 S TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 22:37 **000 CARD # ***** REF: 303748489830 AUTH: 00203497 8000 QUO Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 22:37 3281 96 230 9.49 S 5.79 S 3.49 S 26.75 Join the Safeway Club today. Membership is Free and Instant 0.00 26.75 YOUR CASHIER TODAY WAS SELF 26.75 0.00 5 8896 00328109602302302272237 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00328109602302302272237; total_price: 26.75; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00328109602302302272237; total_price: 26.75; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'ECG DAFNLI2 SAFEWAY S. Store 2218 Dir Charles Martin Main: (808) 623-8111 12913 MR 94-780b Meheula Pkwy MILILANI HI 96789 GROCERY 4 QTY STBX TRIPL DEP SFTDK SNGL FS FEE SFTDK SNGL FS Regular Price Member Savings CHESTERS FLAMIN 2.99 B TAX STORIM **** BALANCE MISCELLANEOUS RCYCBLE BAG CHARGE 19.96 2.00- Credit Purchase 02/27/23 23:46 CARD # ************000 REF: 314628482820 AUTH: 00061091 PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 will sluerisM10381-38 TSI 6800 YOUR SAVINGS 17.96 B 0.20 S 0.04 B Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 23:46 2218 1 15 2695 Member Savings Total Total Savings Value YOUR CASHIER TODAY WAS Lauren Goggar j U>D>-UV-22.34 0.15 T 1.00 22.34 22.34 sibeMtoobnl 0.00 13 2.00 2.00 9% 00221800100152302272346 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru JUTA 0'?
#
# GENERATED:
# receipt_number: 00221800100152302272346; total_price: 22.34; total_tax: 1.0
#
# EXPECTED:
# receipt_number: 00221800100152302272346; total_price: 22.34; total_tax: 1.0
# Token indices sequence length is longer than the specified maximum sequence length for this model (542 > 512). Running this sequence through the model will result in indexing errors
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'MR Albertsons Store 3129 Dir Ron Sousa Main: (661) 827-0394 3500 Panama Lane BAKERSFIELD CA 93313 GEN MERCHANDISE VICKS VAPORUB NSL Regular Price Sale Savings VAPOPATCH ADULT Regular Price 10.99 1.00- MISCELLANEOUS RCYCBLE BAG CHARGE TAX **** BALANCE 11.99 Sale Savings RICOL CGH DROP NTL 2.99 T Regular Price Sale Savings PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 2.00- YOUR SAVINGS 3.29 0.30- Store Savings Total Total Savings Value Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 19:39 3129 52 168 Credit Purchase 02/26/23 19:39 CARD # ************000 REF: 463945436270 AUTH: 00393584 YOUR CASHIER TODAY WAS SELF 9.99 X 9.99 X 24.97 0.10 1.90 24.97 24.97 0.00 3 8852 3.30 3.30 13% 00312905201682302261939 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00312905201682302261939; total_price: 24.97; total_tax: 1.9
#
# EXPECTED:
# receipt_number: 00312905201682302261939; total_price: 24.97; total_tax: 1.9
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'VIBES12042 2013 201 FOU VDAEKLIRIke over 800 313-4568 30 BRAKDAN THO Albertsons siq hoy wel nen Store 212 Dir Gene Tipton eor Main: (702) 395-2700 (EST) MAN HO 8350 West Cheyenne Ave. Las Vegas NV 89129 gynd 23.97 ab10 snilno GROCERY 1002 SIG CLOVER HONEY TREE TOP JUICE SOSO AJUTER 2 QTY GLACEAU SM Regular Price 26.98 Sale Savings 3.00- 2230 ORG GRANOLA COCO TUT GREEN MOUNTAIN Regular Price 11.99 Sale Savings 5.00- UOY TI REFRIG/FROZEN 2939 23.1A2 CHOBANI YGRT VAN G Regular Price Sale Savings PRODUCE 888 A3 BANANAS GREEN PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 7.99 S 3.99 S 23.98 S 6.99 0.50- 2 QTY 1 QTY 24334A3/RASPBERRIES REDT OD 13MU23A A TIMBU2 OT TAX **** BALANCE delez-haubenieudul.. Credit Purchase 02/25/23 11:49 CARD # ************000 REF: 634903480910 AUTH: 00040977 (94.16 YOUR SAVINGS Store Savings Total Total Savings Value 3.99 S 6.99 S Visa ava anneyer .W 0048 estes V CHANGE TOTAL NUMBER OF ITEMS SOLD = 002/25/23 11:49 212 94 75 YOUR CASHIER TODAY WAS SELF 6.49 S Hier 0.67 S 3.50 S 0.00 57.60 57.60 LINS 57.60 0.00 10 8894 8.50 8.50 13% 00021209400752302251149 Thank you for shopping Albertsons ! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru vizulpx [ 101 gnidcol'?
#
# GENERATED:
# receipt_number: 00021209400752302251149; total_price: 57.6; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00021209400752302251149; total_price: 57.6; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'erely Health hen you si Pay cep msung Samsung Pay, Knox, Galaxy Son arks of Samsung Electronics Co., Ltd. App of Apple Inc., registered in the U.S. and oth and the Android Logo are trademarks of Goo SAFEWA enter for more details. onic fund transfer (ACH) payment, if ar financial institution, is subject to a ower, the maximum allowed by law. each unpaid check or returned ACH ronically from your bank account. SAFEWAY S Store 879 Dir Ian Krupnick Main: (719) 593-8805 be 4405 Centennial Blvd Colorado Springs CO 80919 H 1239 clear quantitie a limited s GROCERY SMARTFOOD FLAMIN Regular Price Member Savings SMARTFOOD POPCORN Regular Price Member Savings TOSTITOS_TORTILLA Regular Price Member Savings NBC OREO COOKIES Regular Price Member Savings 3 QTY COCA COLA MR Valued Customer! pleased with everything you purcha providing fresh quality products ev is not as you expected it to be, re ment to your satisfaction. If for son with your shopping experience, nager on duty for assistance. 47 OJMWO 4.99 0.50- REFRIG/FROZEN PAMP EASYUP 4T5T 4.99 0.50- 5.59 0.60- TAX TAX EXEMPTION **** BALANCE FAST FRIES Regular Price 6.99 Member Savings 1.00- GEN MERCHANDISE 4.49 S MISCELLANEOUS 5 QTY DSPSBL BAG PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 4.99 0.20- MEAT LEAN GRND BF 010M LUNCHABLES FUN PK Regular Price 3.99 Member Savings 0.40- DELI CKN WHOLE ROASTED 4.49 S 4.99 S TOPISKE 4.79 S 25.47 B YOUR SAVINGS Member Savings Total 10.99 Visa CHANGE TOTAL TAX TOTAL NUMBER OF ITEMS SOLD = 5.99 S TA_A__ Credit Purchase 02/27/23 17:02 CARD # ************000 REF: 990204419120 AUTH: 00158640 6.48 S 3.59 B YOUR CASHIER TODAY WAS Eren 8.99 T 0.50 1.77 1.77- 80.77 80.77 TAX EXEMPT ID: Not Available 02/27/23 17:02 879 2 143 6269 80.77 0.00 0.00 12 out Payment Options 3.20 3.20 rds 00087900201432302271702 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru Use your PIN-based o to $200 over the epted). v be at the checkout'?
#
# GENERATED:
# receipt_number: 00087900201432302271702; total_price: 80.77; total_tax: 1.77
#
# EXPECTED:
# receipt_number: 00087900201432302271702; total_price: 80.77; total_tax: 1.77
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'CONSUMER GRICULTURAL COMMISSIONER FORMATION DIRECTOR COUNTY ACCURACY TESTED FOR FLOREN OF LOS WEIGHTS AND MEASURES ANGELES Albertsons Store 387 Dir Richard Sage Main (323) 660-0687 Rx (323) 662-5105 2035 Hillhurst Ave. LOS ANGELES CA 90027 GROCERY GATORADE CRV SFTDK 8 PK NTX Regular Price Sale Savings GROC NONEDIBLE REYNOLDS ALUMINUM Regular Price Sale Savings SCOTT BATH TISSUE GEN MERCHANDISE SCTCH BRT SPONGE REUSABLE BAG TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 7.99 0.20- 4.79 0.50- Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 16:16 387 51 168 YOUR SAVINGS Store Savings Total 7.79 S 0.40 S Credit Purchase 02/27/23 16:16 CARD # ************000 REF: 081628415470 AUTH: 00315408 YOUR CASHIER TODAY WAS SELF 4.29 T 5.99 T 3.99 T 0.10 1.36 23.92 23.92 POINTS EARNED TODAY Base Points 22 Total 22 Points Towards Next Reward 22 of 100 23.92 0.00 6 8851 0.70 0.70 00038705101682302271616 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00038705101682302271616; total_price: 23.92; total_tax: 1.36
#
# EXPECTED:
# receipt_number: 00038705101682302271616; total_price: 23.92; total_tax: 1.36
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'CONDU COUPON 93 SAFEWAY S Store 2640 Dir Cinque Ennon Main: (253) 864-7277 Rx:(253) 435-1742 13308 Meridian St E Puyallup WA 98373 MR GROCERY SIG PASTA SAUCE BLUE DOG HEALTH BA. Regular Price 7.29 Member Savings 2.29- GROC NONEDIBLE CASCADE COMPLETE MISCELLANEOUS RCYCBLE BAG CHARGE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 17:37 CARD # ************000 REF: 113722492320 AUTH: 00080621 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 17:37 2640 93 192 YOUR CASHIER TODAY WAS SELF NOW HIRING! See Store Director or visit www.Safeway.com/Careers to apply YOUR SAVINGS Member Savings Total Total Savings Value 10.29 T 19.40 2.49 S 5.00 T 0.08 T 1.54 19.40 19.40 0.00 3 8893 2.29 2.29 11% 00264009301922302271737 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00264009301922302271737; total_price: 19.4; total_tax: 1.54
#
# EXPECTED:
# receipt_number: ; total_price: 19.4; total_tax: 1.54
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '10.00 SAFEWAY S Store 3501 Dir Nick Ericson Main: (253) 838-9941 2109 S.W. 336th St. FFEDERAL WAY WA MR REFRIG/FROZEN LUCERNE WHOLE MILK DELI GAT OPN NAT FLATBREAD MISCELLANEOUS RCYCBLE BAG CHARGE TAX **** BALANCE Join the Safeway Club today. Membership is Free and Instant YOUR CASHIER TODAY WAS SELF 4.49 S 4.29 S Debit Purchase 02/27/23 15:09 CARD # ************000 PRIMARY TOTAL TRANSACTION AMOUNT: 8.87 CASH BACK AMOUNT: 0.00 REF: 690955113840 AUTH: 00115269 Debit CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 15:09 3501 54 99 12U HTIW 32 TROVOA 0.08 T 0.01 8.87 8.87 0.00 2 8854 0035010540099230227150940 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru D'?
#
# GENERATED:
# receipt_number: 0035010540099230227150940; total_price: 8.87; total_tax: 0.01
#
# EXPECTED:
# receipt_number: ; total_price: 8.87; total_tax: 0.01
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Albertsons Store 819 Dir Dennis Stewart Main: (714) 792-2880 Rx: (714) 792-0990 1930 N Placentia Ave FULLERTON CA 92835 GROCERY 2 QTY POPCORNERS Regular Price Sale Savings REUSABLE BAG GEN MERCHANDISE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa 13.18 5.20- Credit Purchase 02/26/23 15:03 CARD # ************000 REF: 440302415810 AUTH: 00559492 YOUR SAVINGS CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 15:03 819 51 100 Store Savings Total Total Savings Value 8.08 YOUR CASHIER TODAY WAS SELF 7.98 S 0.10 0.00 8.08 8.08 0.00 3 8851 5.20 5.20 39% 00081905101002302261503 F Thank you for shopping Albertsons! TSONS FOR U questions call 37 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00081905101002302261503; total_price: 8.08; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00081905101002302261503; total_price: 8.08; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'VARA SAFEWAY S. Store 1559 Dir Raymond Pimpinella Main: (301) 371-3126 815 East Main Street MIDDLETOWN MD 21769 GROCERY LA BNDRTA TRTLAS Regular Price Member Savings WELCHS GRAPE JCE Regular Price Member Savings MISSION SWEET Regular Price Member Savings REFRIG/FROZEN FLORIDAS NATURAL Regular Price Member Savings PLANET OAT MILK CILANTRO EA TAX **** BALANCE PRODUCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa 3.79 0.30- 5.69 2.19- YOUR SAVINGS 2.99 0.49- Member Savings Total Total Savings Value 3.29 0.79- 3.49 S YOUR CASHIER TODAY WAS Becky 3.50 S Credit Purchase 02/27/23 14:38 CARD # ************000 REF: 933857463000 AUTH: 00591227 2.50 S 2.50 S 4.29 S 1.49 S 0.00 17.77 17.77 CHANGE 0.00 TOTAL NUMBER OF ITEMS SOLD = 6 02/27/23 14:39 1559 6 289 5171 17.77 3.77 3.77 18% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY 00155900602892302271439 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00155900602892302271439; total_price: 17.77; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00155900602892302271439; total_price: 17.77; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'AAlbertsons Julio Ojeda Dartagnan ain: (225) 926-9304 Rx:(225) 926-9604 9650 Airline Hwy.WWW Baton Rouge LA 70815 GROCERY SIG COOKIE WAFER COCA COLA CLASSIC 2 QTY MISSION CH REFRIG/FROZEN DAISY SOUR CREAM TAX **** BALANCE PAYMENT AMOUNT AL DEBIT AID A0000000042203 TVR 0000008001 TSI E800 Credit Purchase 02/26/23 14:23 CARD # ************000 REF: 752315444320 AUTH: 00000957 Mastercard CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 14:23 712 52 82 YOUR CASHIER TODAY WAS SELF 2.49 B 2.99 B 7.58 B 2.29 B 0.46 15.81 15.81 15.81 0.00 5 8852 00071205200822302261423 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00071205200822302261423; total_price: 15.81; total_tax: 0.46
#
# EXPECTED:
# receipt_number: 00071205200822302261423; total_price: 15.81; total_tax: 0.46
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'ea 29 EZ. AE Albertsons Store 1948 Dir Bruce Franz Main:(480) 830-5132 Rx:(480) 830-5185 441 N. Val Vista Mesa AZ 85213 GROCERY MILANO DOUBLE MILK Regular Price Sale Savings REFRIG/FROZEN BE STEAMFRESH CORN O ORG CORN ON COB GEN MERCHANDISE GORILLA SPR GLUE G GORILLA GLUE TUBES LOC SUPER GLUE MEAT FARMLAND BCN THK S Regular Price Sale Savings TAX **** BALANCE PAYMENT AMOUNT AL AID A0000000031010 TVR 0000000000 TSI 0000 Visa Credit Purchase 02/25/23 15:27 CARD # ************000 REF: 642754494660 AUTH: 00660131 YOUR CASHIER TODAY WAS CONOR CHANGE AGE VERIFICATION BYPASSED TOTAL NUMBER OF ITEMS SOLD = 02/25/23 15:27 1948 1 166 5546 YOUR SAVINGS 5.79 0.80- 5.99 1.50- Store Savings Total Total Savings Value 34.34 4.99 S 1.41 34.34 2.30 2.30 7% 2.99 S 3.49 S 00194800101662302251527 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru 6.99 T 5.49 T 4.49 T 4.49 S 34.34 0.00 7'?
#
# GENERATED:
# receipt_number: 00194800101662302251527; total_price: 34.34; total_tax: 1.41
#
# EXPECTED:
# receipt_number: ; total_price: 34.34; total_tax: 1.41
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'TEW LOK YOAEBL12me CVIT LOV VOAEBLICIMe cvr SAFEWAY S Store 2979 Dir Ryan Truman Main: (410) 296-2267 Rx: (410) 296-4491 and 1017 York Road TOWSON MD 21204 GEN MERCHANDISE HALLS HONEY LEMON Regular Price 6.49 Member Savings 0.50- TAX **** BALANCE PAYMENT AMOUNT O Credit Purchase 02/28/23 10:46 CARD # ************000 REF: 414622468710 AUTH: 00461439 AL AID A0000000031010 TVR 0000000000 TSI 0000 Visa Total CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/28/23 10:46 2979 4 11 4924 YOUR CASHIER TODAY WAS Craig Member Savings YOUR SAVINGS 5.99 Total Savings Value 187 5.99 Q 0.00 5.99 22341208 3 5.99 0.00 0.50 0.50 8% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY B&W 00297900400112302281046 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru Jura H $75 SEL FREE 8233HO GROCERIES BATOMIRA Refill & refresh in one trip $25 Gift Card with a new or transferred pharmacy prescription, plus a $50 gift card after 5 refills 12 Exclusions Apply: Limit 1 per customer per 12 months. Offer not valid for beneficiaries of state & federal healthcare programs such as Medicare, Medicaid, or Tricare, or if otherwise prohibited by law. Gift card cannot be used for the qualifying transaction, but may be used for future purchases. Gift card cannot be used for prescription co-payments. Offer cannot be copied or replicated. Offer valid at participating locations. Offer not valid for prescriptions previously filled by or transferred from another Albertsons Companies location.'?
#
# GENERATED:
# receipt_number: 00297900400112302281046; total_price: 5.99; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00297900400112302281046; total_price: 5.99; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Albertsons Store 4131 Dir Rickie Farley Main:(323) 295-1919 Rx: (323) 295-3330 3901 Crenshaw Blvd LOS ANGELES CA 90008 GEN MERCHANDISE REUSABLE BAG 2 QTY PULL-UPS L Regular Price Sale Savings TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa Credit Purchase 02/26/23 18:40 CARD # ************000 REF: 464053406700 AUTH: 00029064 27.98 YOUR SAVINGS 2.00- Store Savings Total Total Savings Value YOUR CASHIER TODAY WAS Vicente 15-18 kg 26.08 CHANGE 0.00 TOTAL NUMBER OF ITEMS SOLD = 3 02/26/23 18:40 4131 3 283 7516 0.10 25.98 0.00 26.08 26.08 2.00 2.00 7% 00413100302832302261840 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00413100302832302261840; total_price: 26.08; total_tax: 0.0
#
# EXPECTED:
# receipt_number: ; total_price: 26.08; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'COUPON BOX NOT A TRASH Albertsons Store 3416 Dir Jim Karnes (206) 363-5397 MR 17171 Bothell Way Ne Lake Forest Park WA 98155 REFRIG/FROZEN LUC EGGS LARGE A LUC CREAM CHEESE 2 QTY PLANET OAT Regular Price BAKED GOODS JLPNO CHS BAGELS for U Savings TILLAMOOK CHEDDAR. 10.99 S Regular Price for U Savings MEAT LOF DELI SHVD TRKY. Regular Price for U Savings PRODUCE MISCELLANEOUS 2 QTY RCYCBLE BA GREEN ONIONS Regular Price for U Savings 1.42 lb @ $3.99 /lb WT ORG VINE TOMATOES 1.42 lb @ $1.79 /lb WT ORGANIC RED ONIONS. Regular Price for U Savings TAX **** BALANCE 9.98 1.00- PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 11.99 1.00- 3.49 0.20- YOUR SAVINGS 1.29 0.40- for U Savings Total Total Savings Value 3.96 1.42- Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 13:12 3416 52 63 YOUR CASHIER TODAY WAS SELF 4.99 S 3.49 S 8.98 S Credit Purchase 02/26/23 13:12 CARD # ************000 REF: 191202445380 AUTH: 00768986 47.05 5.99 S 3.29 S 0.89 S 5.67 S 2.54 S 0.20 T 0.02 47.05 NOW HIRING! See Store Director or visit www.Safeway.com/Careers to apply 47.05 0.00 10 8852 **** 4.02 4.02 8% 00341605200632302261312 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00341605200632302261312; total_price: 47.05; total_tax: 0.02
#
# EXPECTED:
# receipt_number: 00341605200632302261312; total_price: 47.05; total_tax: 0.02
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'MA 907 LOM COL YAWA SAFEWAY S Store 309 Dir Ondrea Tainowitz Main:(510) 794-1666 39100 Argonaut Way FREMONT CA 94538 3.3 BUNDABERG ROOTBEER. CRV SFTDK 4 PK TAX 9.99 Regular Price Member Savings 3.00- REFRIG/FROZEN V CRNR WHOLE MILK GROCERY 2001zulax 10), MR 4.99 S 10 PRODUCE 22 292 ylags 1012-ni CAULIFLOWER SMALL tolz ni bils 2.99 S 1.87 lb @ $1.79 /lb GREEN CABBAGE 3.35 S WT 1.11 lb @ $3.49 /lb WT 0.43 3.87 S WT 1.72 S 4.99 S 1.9 RED ROMA TOMATOES lb @ $3.99 /lb GINGER ROOT RASPBERRIES RED MISCELLANEOUS 2 QTY RCYCBLE BA 200 **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 AUTIR14 TVR 8000008000 TSI 6800 6.99 B 0.20 B Credit Purchase 02/27/23 16:11:00 CARD # ************000 REF: 531109416190 AUTH: 00702568 CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 16:11 309 94 92 YOUR CASHIER TODAY WAS SELF YOUR SAVINGS Member Savings Total Total Savings Value 30.04 Visa 30.04 noisomene naibal mont Jailoutiniqe upinu 0.20 0.74 30.04 00030909400922302271611 HO 0.00 8 8894 3.00 3.00 9%  bu A NK'?
#
# GENERATED:
# receipt_number: 00030909400922302271611; total_price: 30.04; total_tax: 0.74
#
# EXPECTED:
# receipt_number: 00030909400922302271611; total_price: 30.04; total_tax: 0.74
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '2YEMVA 1234 MD7 EOB VDAEB112IMG CYFT 36V FLEST VE LEVA123 DT LOE VOAEBLIZIME C SAFEWAY S 2937 Store 1574 Dir Michelle Sukovaty Main:(408) 267-1200 4950 Almaden Expressway SAN JOSE CA 95118 GROCERY AM BLUE DOG CHKN & BR REFRIG/FROZEN LUCERNE CAGE FREE AISIA TAX 3.94 **** BALANCE to ne bilo 20 52.92 PAYMENT AMOUNT  AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 18:00 CARD # ************000 REF: 580026441720 AUTH: 00244805 Visa JOY 41.99 T CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 18:00 1574 94 87 6.99 S 52.92 Join the Safeway Club today. Membership is Free and Instant YOUR CASHIER TODAY WAS SELF 2 52.92 0.00 2 8894 Mer 00157409400872302271800 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00157409400872302271800; total_price: 52.92; total_tax: 3.94
#
# EXPECTED:
# receipt_number: 00157409400872302271800; total_price: 52.92; total_tax: 3.94
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Albertsons Store 110 Dir Joe Bisera Main: (714) 536-6449 Rx: (714) 536-3679 7201 Yorktown Avenue HUNTINGTON BEACH CA 92648 GROCERY PURE LIFE WATER CRV SFTDK SNGL NTX GEN MERCHANDISE REUSABLE BAG EDGE GEL TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 18:30 CARD # ************000 REF: 473026463480 AUTH: 00323592 9.93 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 18:30 110 53 170 YOUR CASHIER TODAY WAS SELF ||||||| 3.49 S 0.10 S 0.10 5.79 T 0.45 9.93 9.93 0.00 4 8853 00011005301702302271830 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru COUP 5'?
#
# GENERATED:
# receipt_number: 00011005301702302271830; total_price: 9.93; total_tax: 0.45
#
# EXPECTED:
# receipt_number: 00011005301702302271830; total_price: 9.93; total_tax: 0.45
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'COUPON 333 ste s Albertsons Store 3324 Dir Armando Pulido Main:(805) 693-1069 222 East Highway 246 BUELLTON CA 93427 GROCERY NBC WHEAT THINS Resular Price 5.99 Member Savings 1.00- REFRIG/FROZEN KRAFT CHEESE HORIZON ORG MLK GEN MERCHANDISE REUSABLE BAG TAX **** BALANCE BAKED GOODS WHITE BREAD NTR OW 4.79 S DELI PORT WINE CHSE CUP 5.49 S Regular Price 5.99 Member Savings 0.50- PAYMENT AMOUNT AL AID A0000000031010 TVR 0000000000 TSI 0000 Credit Purchase 02/27/23 20:16 CARD # ****** ****000 REF: 531621445630 AUTH: 00545582 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 20:16 3324 52 207 YOUR CASHIER TODAY WAS SELF 4.99 $ YOUR SAVINGS 6.99 S 6.49 S Member Savings Total Total Savings Value 0.10 28.85 0.00 28.85 28.85 0.00 6 8852 1.50 1.50 5% 00332406202072302272016 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00332406202072302272016; total_price: 28.85; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00332406202072302272016; total_price: 28.85; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY S Store 1579 Dir Amanda Gayle Main: (301) 916-8584 Rx: (301) 916-8587 19718 Germantown Road GERMANTOWN MD 20874 GROCERY 2 QTY 00 GARBANZ 4 QTY O ORG CHIC Regular Price 10.00 Member Savings 2.00- SEAFOOD 2 QTY GORTONS PR Regular Price Member Savings PRODUCE AVOCADOS HASS TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa Credit Purchase 02/27/23 19:05 CARD # ******* ***000 REF: 360543496340 AUTH: 00964640 21.98 10.99- CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 19:05 1579 94 162 YOUR SAVINGS YOUR CASHIER TODAY WAS SELF Member Savings Total Total Savings Value 3.58 S 8.00 S 10.99 S 4.99 S 0.00 27.56 27.56 27.56 0.00 9 8894 12.99 12.99 32% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY 00157909401622302271905 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru O'?
#
# GENERATED:
# receipt_number: 00157909401622302271905; total_price: 27.56; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00157909401622302271905; total_price: 27.56; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'bet 192 & bean stan bvia noti que woarr SAFEWAYS. Store 253 Dir Jonathan Boggess Main:(480) 982-6120 Rx: (480) 288-2728 3185 W. Apache Trail APACHE JUNCTION AZ 85220 GROCERY noi OST SAMT DEW CODE RED T e cvri Regular Price TE-7.9908:4 Member Savings 1.00- NBC OREO COOKIES Regular Price ATE 6.49 Member Savings 1.50- 223M12 REFRIG/FROZEN TAVA UT LUC LUC COTTAGE CHEESE 1 QTY MATTEL HOT WHEELS (AS) 20 MACCHUDP MEAT 1 QTY GEN MERCHANDISE BAR-S FRANKS TAX **** BALANCE 13220 PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 6.99 B 4.99 B Credit Purchase 02/27/23 19:09 CARD # ****** **000 REF: 890928445820 AUTH: 004066324ANOXIA BIEDT DS 3.49 B YOUR SAVINGS Member Savings 2.40% SALES TAX 6.70% SALES TAX TOTAL TAX TOTAL NUMBER OF ITEMS SOLD = 02/27/23 19:09 253 54 268 Total 80- Total Savings Value 1.25 T 1.00 B 0.51 18.23 22ALD OTUA Visa DOA'S 18.23 CHANGE 18.23 YOUR CASHIER TODAY WAS SELF 0.00 0.43 0.08 0.51 5 8854 2.50 2.50 12% 00025305402682302271909 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru VOO 94 s'?
#
# GENERATED:
# receipt_number: 00025305402682302271909; total_price: 18.23; total_tax: 0.51
#
# EXPECTED:
# receipt_number: ; total_price: 18.23; total_tax: 0.51
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'ire all individuals t ase alcoholic bever: require identification beverages. OUR RE y be requirer nd exchange AN GUAF ans higher than t m at the lowest p h item, excludes tob s to advertised or s ons. ACTURER COUPO s reserves the right to r facturer coupons duplic ation of the redemption edeemed only for the ar met a cash credit or pay ied against any free iter axes will be applied in a less of any coupon or a action. plicable bottle and pack be paid by the custome EN YOAEBLIZIMG cyrr 600-545-4383 12803 BAY EBER BVLER VEBEB 2012 2013  LOB VDAEB12 Vr 300-3-83 10083 BBV EBEE BVBEK   LO   ETOH SURAD 20 IUTA duz llsm2 6. 1991 Albertsons Store 212 Dir Gene Tipton Main:(702) 395-2700 8350 West Cheyenne Ave. Las Vegas NV 89129 noites LOMSCOBRIA 140113 GROCERY yel1 sipood) sibeMappbril MOTTS APL JCE Regular Price Sale Savings CHEETOS CRUNCHY LANGERS APL ORNG 190 BARCEL TAKIS BLUE Regular Price Deas* Sale Savings 215 Sonbays AAA-ARS-SOF Sale Savings FIORA ULT SFT BT Regular Price GROC NONEDIBLE 190.002199 PRODUCE and gori2 ria GRAPES RED 2LB 9VA ennsyen3 W 0048 estes VM. TAX VM TAXIV 26. **** BALANCE MASAL 010/204.29 S 4.79 0.50- 3.99 0.99- 5.49 0.50-og aba oynissiq 03 10inq 1911o aid in92910 926919.ES12E 29miqx3 10 1910 vns rijlw bilay 10M bojal SOSSOSO bsbuionis AX3H 201 210 pulsy Visa eitto 1132 Credit Purchase 02/26/23 17:55 betoon YOUR SAVINGS Store Savings Total Total Savings Value  MSTOOL anoitssol elewbis na gnisqichqis AL VISA CREDITlibes, nemoteus neq naqueo eno fint AID A0000000031010 TVR 8000008000 TSI 6800 5.69 S 4.99 S 3.00 S CARD # ************000 REF: 165544431000 AUTH: 00967287 Cr pea0 asoe 9261   PAYMENT AMOUNT 202 to 4.99 T CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 17:55 212 5 67 8808 4.99 S ---- YOUR CASHIE YOUR CASHIER TODAY WAS Brenda 28.37 9.00- 0.42 28.37 28.37 0.00 6 1.99 1.99 7% 00021200500672302261755 Thank you for shopping Albertsons! 877-276-9637 or Albertsons.com/foru ons PO any other tobacco der the age of 21. If you to look under the age ared to present a valid 25/0 We Accept VISA ER MasterCard AMERICAN EXPRESS SAMSUNG pay ATM/Debit Cards Pay Pay to LVMC 10.76.0.10, rson to drink or posse of alcoholic beverage ises, the parking lot, leet of the premises. THE FOLLOWING EXCEP to redeemt two or more manufac ction, the highest discount for th cies for manufacturer coupons a been loaded to club card. printed manufacturer coupons. of scanning at checkout and m ndustry-standard format. nformation, see Service Desk.'?
#
# GENERATED:
# receipt_number: 00021200500672302261755; total_price: 28.37; total_tax: 0.42
#
# EXPECTED:
# receipt_number: ; total_price: 28.37; total_tax: 0.42
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'BEBIZON2 SUS EWY EOB VDAEBLIZING CYFT JAO DHIRITREVOA 909 AMA SUSA MOTERODA Albertsons Store 1262 Dir AJ Flores Main:(817) 354-0622 Rx: (817) 354-0991 1300 Airport Fwy BEDFORD TX 76022 GROCERY AQUAFINA WTR CASE KD BURST TROP PNCH 3 MEAT  X  UOY PRODUCE SPICE WORLD GARLIC TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa Of Credit Purchase 02/26/23 18:31 CARD # ************000 REF: 633121416290 AUTH: 00226314 6.99 S 1.69 B CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 18:31 1262 54 117 R YOUR CASHIER TODAY WAS SELF 7.99 S 2 4.99 S 21.80 0.14 21.80 ONLILEIAV 21.80 0.00 4 8854 00126205401172302261831 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru PATH ROMILLEJEM'?
#
# GENERATED:
# receipt_number: 00126205401172302261831; total_price: 21.8; total_tax: 0.14
#
# EXPECTED:
# receipt_number: 00126205401172302261831; total_price: 21.8; total_tax: 0.14
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Albertsons Store 2543 Dir Gabino Lugo Main:(626) 293-7100 Rx: (626) 576-3900 2400 West Commonwealth Ave. ALHAMBRA CA 91803 ve, 6910 GROCERY RKS COFF STRBKS COFF K CP B Regular Price Sale Savings REUSABLE BAG GEN MERCHANDISE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 OM Visa 11.99 2.00- 19 Credit Purchase 02/27/23 09:06 CARD # ******* ***000 REF: 540643449610 AUTH: 00774166 9.99 S YOUR SAVINGS 0.10 0.00 10.09 2qil 10.09 CHANGE To 0.00 TOTAL NUMBER OF ITEMS SOLD = 2 02/27/23 09:06 2543 53 18 TUSHIAH YMA YOUR CASHIER TODAY WAS SELF 10.09 POINTS EARNED TODAY Base Points 9 Total 9 Points Towards Next Reward 9 of 100 8853 Store Savings Total gai Total Savings Value nalepitie Asow 10 17% 18 2.00 2.00 00254305300182302270906 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru zqil J5912'?
#
# GENERATED:
# receipt_number: 00254305300182302270906; total_price: 10.09; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00254305300182302270906; total_price: 10.09; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'WIE 000033**** 200 SAFEWAYS. Store 3298 Dir Christel Chandler Main:(425) 355-7622 Rx: (425) 595-3223 WT 4 QTY LIMES 0.46 lb @ $1.49 /lb 2 QTY 7601 Evergreen Way Everett WA 98203 RED ROMA TOMATOES GARLIC BULK TAX **** BALANCE PRODUCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 *** Credit Purchase 02/27/23 18:16 CARD # ******* ***000 REF: 861654488930 AUTH: 00270352 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 18:16 3298 52 158 *** 5.45 2.76 S 0.69 S 2.00 S 0.00 5.45 YOUR CASHIER TODAY WAS SELF NOW HIRING! See Store Director or visit www.Safeway.com/Careers to apply 5.45 0.00 7 8852 **** ****** 00329805201582302271816 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru V'?
#
# GENERATED:
# receipt_number: 00329805201582302271816; total_price: 5.45; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00329805201582302271816; total_price: 5.45; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY Store 1591 Dir Carlton Hurst Main: (602) 268-0022 Rx: (602) 268-0634 6202 South 16th Street Phoenix AZ 85040 2 QTY SIG DISTILLED WATR 4 QTY CMPBL CHUN . Regular Price Member Savings GROCERY REFRIG/FROZEN 2 QTY LUC HARD C PRODUCE 2 QTY CELERY MED TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa 13.96 2.00- Credit Purchase 02/27/23 15:43 CARD # ************000 REF: 834319402530 AUTH: 00868313 CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 15:43 1591 51 63 YOUR CASHIER TODAY WAS SELF YOUR SAVINGS Member Savings Total Total Savings Value 3.34 S 11.96 S 10.98 S 0.00 30.26 30.26 3.98 S CD 30.26 0.00 10 8851 2.00 2.00 6% 00159105100632302271543 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00159105100632302271543; total_price: 30.26; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00159105100632302271543; total_price: 30.26; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'E FYTYYTE (2 HONE APPS 3 A DISC: USB * iPhone 81 Media B  x Shuffle crazy Zac Gi crazy 1/1 PM 00:0 AUTO Chap Stick Albertsons Store 590 Dir Chad Onchi Main:(503) 591-7557 Rx: (503) 591-0997 MR 7500 E Main St Hillsboro OR 97123 GRANOLA BAR TAX **** BALANCE ON/ OFF REFRIG/FROZEN 2 QTY LUC WHOLE LUC YOGURT STRWBRY Regular Price You Save PAYMENT AMOUNT GROCERY MISCELLANEOUS RCYCBLE BAG CHARGE 0.10 0.00 14.36 On Credit Purchase 02/28/23 07:33 CARD # ************000 bom100bni of of REF: 953328421740 AUTH: 00854941 SYNC ----- AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Store Savings Total YOUR CASHT MOUNT 374 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/28/23 07:33 590 51 3  YOUR CASHIER TODAY WAS SELF YOUR SAVINGS 2.79 0.30- * < >$ 14.36 CLAW DROGE VORO 723807 02/27/23 15 TOTAL NUME ||||| 00059005100032302280733 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru ANYARA MODE Na NOUTAN BOL 4.99 S 6.78 S 2.49 S 14.36 50016 NO OBLIN 18 A TUR TSI 6 TVR AID AL 0.00 8851 0.30 0.30 11 A/C FRONT 02:37 NOLUA Patric OUT TEMP MAX A/C OREGON Change Device 36F GAME Browse LOTTERY POWER BALL * Repeat for a chance t and other exc 09 no Ta 86 HOLD TUNE/SCF RADIO  K'?
#
# GENERATED:
# receipt_number: 00059005100032302280733; total_price: 14.36; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00059005100032302280733; total_price: 14.36; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY S Store 2684 Dir Jake Cantrell Main: (916) 492-9967 Rx: (916) 492-9977 1814-19th St. SACRAMENTO CA 95814 MR REFRIG/FROZEN 3 QTY HAAGEN DAZ MISCELLANEOUS RCYCBLE BAG CHARGE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 21:30 CARD # ************000 REF: 123026427470 AUTH: 00804749 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 21:30 2684 93 292 20.97 S YOUR CASHIER TODAY WAS SELF 0.10 0.00 21.07 21.07 W 21.07 0.00 3 8893 00268409302922302272130 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru 1010M ovs2 3 910M brieq? 04392'?
#
# GENERATED:
# receipt_number: 00268409302922302272130; total_price: 21.07; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00268409302922302272130; total_price: 21.07; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '16 400 01 FOK YDAFK Liene CVT 8005434203 FOR YOACE ACCY FORM STATED FOR  , !   MU23R A TIMBU2 OT GEOT- URNT 3V Store 3301 Dir Danny Almada Main:(661) 775-0163 Rx: (661) 775-3944 23850 West Copper Hill Road VALENCIA CA 91355 IT bio sHT 8E08S 602.www moa GROCERY 812 HEKNOR CH POLO DIA 29 deswis asbutant REFRIG/FROZEN NUEVO  Albertson 2 QTY 4 LUC PARMSAN CHEESE Regular Price Sale Savings LUC WHIP CREAM HVY QTY 1.28 lb @ $1.99 /lb REUSABLE BAG GEN MERCHANDISE AW 2 PRODUCEH RED ROMA TOMATOES GARLIC BULK JALAPENO PEPPERS CILANTRO BUNCHED TAX **** BALANCE 3.99 0.20- PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 SH TVR 8000008000 TSI 6800 nesW XRAQ 3.79 S 4.99 S 0.10 GUAT balonl 168 El 2.55 S 1.00 S 1.00 S 0.99 S Credit Purchase 02/25/23 17:04 CARD # ************000 REF: 800418465840 AUTH: 00148941 0.00 18.71 18.71 dasW 91T 3 18.71 Visa rasW e81 ORGNO CHANGE BB 0.00 TOTAL NUMBER OF ITEMS SOLD = 12 02/25/23 17:04 3301 3 169 2088 ATBIRO YOUR CASHIER TODAY WAS Isaiah (Powod of 1RBM YOUR SAVINGS Store Savings Total 6907 AGT M340 0.20 0.20 00330100301692302251704 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru 2 103'?
#
# GENERATED:
# receipt_number: 00330100301692302251704; total_price: 18.71; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00330100301692302251704; total_price: 18.71; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# ...
#
# GENERATED:
# receipt_number: 00151317500172302281037; total_price: 28.54; total_tax: 0.93
#
# EXPECTED:
# receipt_number: 00151317500172302281037; total_price: 28.54; total_tax: 0.93
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '+ 1.75 E ON A MAC CS1-18  BEH YEBEK12002 2003 DE 300-3-1-410311020 VTBEBIZON2 2000 DIE EOB VDAEBI12IMG Cy 132A110801 AAlbertsons Store 4009 Dir Margaret Benedict Main: (702) 658-2030 Rx: (702) 658-6669 8410 Farm Road 118 Las Vegas NV 89131 SW 180 Far Va GROCERY 101 4 QTY SIG WTR PU REFRIG/FROZEN HA BLUE DIAMOND ALMD Regular Price Sale Savings TAX **** BALANCE AMADIR PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 68001 Credit Purchase 02/26/23 19:15 byens CARD # ************000m bns obulitis yage moy REF: 991530438060 AUTH: 00217062 MOD.2A03VWOROWOHZ Store Savings Total Visit RAD JEM POST 4.49 0.50- YOUR SAVINGS worl2 T238 ZAGV CAT Zaz TOTAL NUMBER OF ITEMS SOLD = 02/26/23 19:15 4009 96 32AHJAUS 211UTIW 211 1049 190-1012 YOUR CASHIER TODAY WAS SELF www.w 19iden3 91012 of qqs TUTA Visas AS9V2A3.09 35 23.95 DANCE YOU CHANGE 19.96 S 23.95 vanom 1028 160 baills-blo3 0.00 23.95 dovleast framegane cos869 vidi M anato odio dhe banidino so of roll triglic 31000000 A16A estig SASO-aea-25 YAW MATIRAO 3.99 S BOW For ALBERTSONS FOR U questions ca 0.00 50 00400909602112302261915 Thank you for shopping Albertsons! mos.VJesibl 0.50 0.50 8896 INHUOL WAN H 877-276-9637 or Albertsons.com/foru 12 18 NE a y H 2'?
#
# GENERATED:
# receipt_number: 00400909602112302261915; total_price: 23.95; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00400909602112302261915; total_price: 23.95; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in '20% OFF PER GALLON REWARD Sign up for Albertsons for U and receive $0.20/gallon off at the pump after your first purchase!* Click on deals, click on for U and claim this exclusive offer. *Valid only for new Albertsons for U members. One time use. Limit 1 per household. Restrictions apply. Visit www.Albertsons.com/foru-guest.html for full offer terms and conditions. Albertsons for U account, points accrual, and Rewards redemption including redemption on gas and groceries, are subject to the program terms and conditions found at www.Albertsons.com/foru-guest.html $5 OFF Sign up with Albertsons for U and receive $5 Off your next purchase of $25 or more* Click on deals, click on for U and claim this exclusive offer. *Valid only for new Albertsons for U members. One time use. Limit 1 per household. Restrictions apply. Visit www.Albertsons.com/foru-guest.html for full offer terms and conditions. Albertsons for U account, points accrual, and Rewards redemption including redemption on gas and groceries, are subject to the program terms and conditions found at www.Albertsons.com/foru-guest.html . Albertsons Store 662 Dir Beka Abdu Main: (702) 792-7156 Rx: (702) 796-2952 2885 East Desert Inn Las Vegas NV 89121 PRODUCE 2 QTY GTS KOMBUC Regular Price Sale Savings 2 QTY GTS SYNERG Regular Price Sale Savings TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 7.98 0.98- 7.98 0.98- Credit Purchase 02/27/23 20:44 CARD # ************000 REF: 034401445430 AUTH: 00687722 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 20:44 662 52 260 YOUR SAVINGS Store Savings Total Total Savings Value YOUR CASHIER TODAY WAS SELF 7.00 S 1 7.00 S 0.00 14.00 14.00 POINTS EARNED TODAY Base Points 14 Total 14 Points Towards Next Reward 14 of 100 14.00 0.00 4 8852 1.96 1.96 12% 00066205202602302272044 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00066205202602302272044; total_price: 14.0; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00066205202602302272044; total_price: 14.0; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Store 2795 Dir Richard Lewis Main:(301) 574-1351 Rx:(301) 574-0250 7605 Crain Highway UPPER MARLBORO MD 20772 GROCERY 2 QTY MAR YAKISO. 2.67 S Regular Price 2.98 Member Savings 0.31- REFRIG/FROZEN LUC CHOC MILK 2% MEAT LUNCHABLES BASIC. 3.29 S Regular Price 3.99 Member Savings 0.70- PRODUCE WATERMELON BOWL TAX **** BALANCE Credit Purchase 02/27/23 16:23 CARD # ************000 REF: 942305492010 AUTH: 00670911 PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 16:23 2795 52 185 YOUR CASHIER TODAY WAS SELF YOUR SAVINGS 16.54 Member Savings Total Total Savings Value 5.99 S 0.00 16.54 4.59 S 16.54 0.00 5 8852 1.01 1.01 6% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY 00279505201852302271623 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00279505201852302271623; total_price: 16.54; total_tax: 0.0
#
# EXPECTED:
# receipt_number: ; total_price: 16.54; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'AAlbertsons Store 2952 Dir Robert Flyr Main:(602) 678-0895 Rx: (602) 678-0594 8035 N. 19th Avenue Phoenix AZ 855021 MEAT GR BEEF 80%LN CLUB 8.22 S Regular Price 13.83 Sale Savings 5.61- TAX **** BALANCE Credit Purchase 02/27/23 18:01 CARD # ************000 REF: 250110423220 AUTH: 00731271 PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 18:01 2952 54 169 8.22 YOUR CASHIER TODAY WAS SELF YOUR SAVINGS Store Savings Total Total Savings Value 0.00 8.22 8.22 0.00 8854 5.61 5.61 41% 00295205401692302271801 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00295205401692302271801; total_price: 8.22; total_tax: 0.0
#
# EXPECTED:
# receipt_number: ; total_price: 8.22; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'EBEE BYLEK YAWSHAS LOS VDAEUMaine cvrt P00 Sex 2VEEMVA 833 AMB LOB VDAEB112MG CYTE 33AM DET SAFEWAY S Store 923 Dir Charmaine Main: (202) 667-6825 1701 Corcoran Street Nw WASHINGTON DC 20009 PEPSI SODA RUFFLES CRSP POT Regular Price Member Savings 2 QTY OREO FS GO Regular Price Member Savings GROCERY REFRIG/FROZEN HF TRK HNY ULT Regular Price Member Savings CA TXE MR MISCELLANEOUS 5 QTY DSPSBL BAG TAX **** BALANCE OATLY NON DAIRY FU 3 QTY DANNON OIK Regular Price Member Savings BE LIQUID EGG WHIT. 3.49 S Regular Price Member Savings BREYERS ICE CRM Regular Price Member Savings MEAT AYAS-BEE PAYMENT AMOUNT AL AID A0000000031010 TVR 0000000000 TSI 0000 Visa 12.18 4.19 0.40- 4.18- YOUR SAVINGS Member Savings Total Total Savings Value ATAS- 6V 5.49 S 2.67 S 5.67 3.00- 3.99 0.50- 4.69 1.10- 2.99 B 3.79 S 6.99 1.00- Credit Purchase 02/27/23 21:06 CARD # ************000 REF: 720638489440 AUTH: 00792672 8.00 S YOUR CASHIER TODAY WAS SELF 3.59 S 5.99 S 0.25 0.24 36.50 36.50 ------------------- YRTITO DEM200 & IMA CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 21:06 923 51 206 688 8851 Oer 36.50 0.00 11 10.18 10.18 22% HOW WAS YOUR SHOPPING EXPERIENCE? WE VALUE YOUR FEEDBACK! SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY 6Vo9 DIAM200 & YURMAR cre ||||||| 00092305102062302272106 moH a Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru V'?
#
# GENERATED:
# receipt_number: 00092305102062302272106; total_price: 36.5; total_tax: 0.24
#
# EXPECTED:
# receipt_number: ; total_price: 36.5; total_tax: 0.24
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'ENVOYDAEBLIZI Albertsons H2AW 170 MERFRORJAH Store 981 Dir Casey Dietz AMTRCBJA 1.Jemolaup 190 naque C Main: (480) 899-7102 Rx:(480) 899-7713 3145 S Alma School Road Chandler AZ 85248 85248 T GEN MERCHANDISE AVEENO BODY WASH CORA TMPNS DUO PK TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/26/23 12:18 CARD # ************000 REF: 381854491340 AUTH: 00491471 Visa AHO 10.99 T 12.99 X Moson CHANGE 1.5% SALES TAX 6.3% SALES TAX TOTAL TAX TOTAL NUMBER OF ITEMS SOLD = 02/26/23 12:18 981 54 76 YOUR CASHIER TODAY WAS SELF 1.87 25.85 MAK 25.85 25.850NON 000 a 0.00 0.36 1.51 1.87RA 8854 2 00098105400762302261218 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru seluayingsini-warnia 100 10 S'?
#
# GENERATED:
# receipt_number: 00098105400762302261218; total_price: 25.85; total_tax: 1.87
#
# EXPECTED:
# receipt_number: ; total_price: 25.85; total_tax: 1.87
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'COUPON 52 AAlbertsons Store 798 Dir Hassan Ayoub Main: (951) 245-4461 Rx: (951) 245-5492 30901 Riverside Drive LAKE ELSINORE CA 92530 1 QTY GROCERY TRIDENT GUM MINTY Regular Price Sale Savings RUFFLES POTATO Regular Price Sale Savings Sale Savings TWIX CARAMEL SKITTLES BITE SIZE 0.99 S Regular Price Regular Price Sale Savings IBC ROOT BEER CRV SFTDK 4 PK TAX REFRIG/FROZEN 2 QTY REUSABLE B DELI 2 QTY F CRML TRA Regular Price Sale Savings TAX **** BALANCE 2.00 0.75- SIG IC CRM SANDWCH Regular Price Sale Savings 5.59 0.30- PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 GEN MERCHANDISE nutes 1.79 0.80- 1.79 0.80- YOUR SAVINGS Store Savings Total Total Savings Value 5.99 0.50- 10.98 1.00- 1.25 S Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 08:26 798 52 5 5.29 S YOUR CASHIER TODAY WAS SELF 0.99 S Credit Purchase 02/26/23 08:26 CARD # ******** ***000 REF: 172629498060 AUTH: 00918978 4.29 B 0.20 B 5.49 S 0.20 9.98 S 0.39 29.07 29.07 laneqgoria emit tant not 29.07 0.00 11 8852 4.15 4.15 13% 00079805200052302260826 Thank you for shopping Albertsons! ALBERTSONS FOR U questions call Albertsons.com/foru 276-9637 or'?
#
# GENERATED:
# receipt_number: 00079805200052302260826; total_price: 29.07; total_tax: 0.39
#
# EXPECTED:
# receipt_number: ; total_price: 29.07; total_tax: 0.39
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'AAlbertsons Store 2997 Dir Patty Prince Main:(480) 491-1026 Rx: (480) 491-1510 4060 W. Ray Road Chandler AZ 85226 MEAT NY STRIP STK BI CL PRODUCE SIG POTATOES BITE 0.65 lb @ $1.49 /lb WT RED POTATOES TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/26/23 18:35 CARD # ************000 REF: 243554476790 AUTH: 00420673 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/26/23 18:35 2997 93 160 YOUR CASHIER TODAY WAS SELF 43.85 B 3.99 B 0.97 B 0.73 49.54 49.54 49.54 0.00 3 8893 00299709301602302261835 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru 93 2021 2022'?
#
# GENERATED:
# receipt_number: 00299709301602302261835; total_price: 49.54; total_tax: 0.73
#
# EXPECTED:
# receipt_number: 00299709301602302261835; total_price: 49.54; total_tax: 0.73
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'Albertsons Store 2591 Dir John Lewis Main:(949) 733-0698 Rx: (949) 733-0945 14201 Jeffrey Road IRVINE CA 92620 GROCERY GUERRERO RIQUISIMA SOFT TACO 10 QTY ALKALINE88 CRV SFTDK SNGL NTX Regular Price 57.90 Sale Savings 8.00- REFRIG/FROZEN KNUD SR CRM Regular Price Sale Savings TILLAMOOK CHEESE Regular Price Sale Savings GEN MERCHANDISE Sale Savings ORG STRAWBERRIES 0 ORG BLUEBERRIES 6 QTY REUSABLE B PRODUCE ICEBERG LETTUCE 5 QTY BLACKBERRI Regular Price 19.95 2.45- TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 3.49 0.50- 8.99 0.50- 4.99 S 3.79 S 49.90 S 1.00 S Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/24/23 17:49 2591 94 107 YOUR SAVINGS Store Savings Total Total Savings Value YOUR CASHIER TODAY WAS SELF 2.99 S 8.49 S Credit Purchase 02/24/23 17:49 CARD # ************000 REF: 024953421540 AUTH: 00750268 0.60 1.99 S 17.50 S 6.99 S 4.99 S 0.00 103.23 103.23 103.23 POINTS EARNED TODAY Base Points 101 Total 101 Points Towards Next Reward 101 of 100 0.00 38 8894 11.45 11.45 10% ||||| 00259109401072302241749 Thank you for shopping Albertsons! For ALBERTSONS FOR U questions call 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00259109401072302241749; total_price: 103.23; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00259109401072302241749; total_price: 103.23; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# What are the receipt_number, total_price, and total_tax in 'SAFEWAY S Store 333 Dir Rob Knapp Main: (509) 946-9605 Rx: (509) 946-1157 1803 George Wash. Wy Richland WA 99352 GEN MERCHANDISE MR PEPTO BISMOL LIQ TUMS ANTACID PRODUCE 1.00 lb @ $0.69 /lb WT BANANAS GREEN 0.97 lb @ $1.99 /lb WT NAVEL ORANGES MISCELLANEOUS RCYCBLE BAG CHARGE TAX **** BALANCE PAYMENT AMOUNT AL VISA CREDIT AID A0000000031010 TVR 8000008000 TSI 6800 Credit Purchase 02/27/23 17:08 CARD # ************000 REF: 140829431350 AUTH: 00335749 Visa CHANGE TOTAL NUMBER OF ITEMS SOLD = 02/27/23 17:08 333 93 128 Join the Safeway Club today. Membership is Free and Instant YOUR CASHIER TODAY WAS SELF 10.84 4.49 T 2.99 X 122 1208 0.69 S 1.93 S 0.08 T 0.66 10.84 10.84 0.00 4 8893 00033309301282302271708 Thank you for shopping Safeway! For SAFEWAY FOR U questions call 877-276-9637 or Safeway.com/foru 32/7/3/0 [UR'?
#
# GENERATED:
# receipt_number: 00033309301282302271708; total_price: 10.84; total_tax: 0.66
#
# EXPECTED:
# receipt_number: 00033309301282302271708; total_price: 10.84; total_tax: 0.66

# %%
def str_to_json(js, do_print_exception=False):
    res = {}
    for ss in js.lower().split(";"):
        try:
            k, v = ss.split(":")
            if k.strip() in ["total_price", "total_tax"]:
                res[k.strip()] = float(v.strip())
            else:
                res[k.strip()] = v.strip()
        except:
            if do_print_exception:
                print(js)
    return res
str_to_json("receipt_number: 00400505302182302271921; total_price: 10.98; total_tax: 0.0")
# Out:
# {'receipt_number': '00400505302182302271921',
#  'total_price': 10.98,
#  'total_tax': 0.0}

# %% [markdown]
# #  Compute accuracy based on instruction on goldern dataset

# %%
statistics = {"receipt_number": 0, "total_price": 0, "total_tax": 0}
count  = 0
for d in test_data['test']:
    input_text= d["input_text"]
    generated = str_to_json(generate_transcipt_response(input_text, model, tokenizer), True)
    expected = str_to_json(d['output_text'])
    for k, v in expected.items():
        if k in generated and v == generated[k]:
            statistics[k] += 1

# %%
for k, v in statistics.items():
    print(f"=========Correctly extracted {v} {k} among {len(test_data)}, accuracy is {v/len(test_data['test'])} ")
# Out:
# =========Correctly extracted 349 receipt_number among 2, accuracy is 0.8329355608591885
# =========Correctly extracted 416 total_price among 2, accuracy is 0.9928400954653938
# =========Correctly extracted 414 total_tax among 2, accuracy is 0.9880668257756563
