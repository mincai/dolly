# %%
import sys
import os
import numpy as np

SCRIPT_DIR = os.path.dirname(os.path.abspath("..."))
sys.path.append(os.path.dirname(SCRIPT_DIR))

from datasets import load_from_disk
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
    T5ForConditionalGeneration
)

# %% [markdown]
# # Load test dataset that is unseen in train

# %%
test_data = load_from_disk("/opt/home/bo_ling/dataset/eats_receipt_gcp_v3_test.hf")
test_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 3
#     })
#     test: Dataset({
#         features: ['input_text', 'output_text'],
#         num_rows: 350
#     })
# })

# %%
test_data['test'][0]
# Out:
# {'input_text': "Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons\nStore 199 Dir BRIAN CONLEY\n1219 Broadway Avenue\nBOISE ID 83706\n(208)336-5278\nGROCERY\nLACROIX 8PK\n4.59 B\n2 QTY SIG WATER\n5.98 B\nRegular Price\n7.58\nYou Save\n1.60-\nBARILLA PASTA\n1.99 B\nRegular Price\n2.49\nYou Save\n0.50-\nREFRIG/FROZEN\n5.29 B\nCREAM CHEESE\nTAX\n1.07\nTAX EXEMPTION\n1.07-\n**** BALANCE\n17.85\nCredit Purchase 02/26/23 14:26\nCARD # ************000\nREF: 882607465070 AUTH: 00736188\nPAYMENT AMOUNT\n17.85\nAL VISA CREDIT\nAID A0000000031010\nTVR 8000008000\nTSI 6800\n17.85\nVisa\n0.00\nCHANGE\nTOTAL NUMBER OF ITEMS SOLD = 5\nTAX EXEMPT ID: ***\n***000\n02/26/23 14:26 199 1 102 8729\nYOUR CASHIER TODAY WAS JACK\nYOUR SAVINGS\n2.10\nStore Savings\n2.10\nTotal\n11%\nTotal Savings Value\n00019900101022302261426\nThank you for shopping Albertsons!\nFor ALBERTSONS FOR U questions call\n877-276-9637 or Albertsons.com/foru'?",
#  'output_text': 'receipt_number: 00019900101022302261426; total_price: 17.85; total_tax: 1.07'}

# %% [markdown]
# # Load trained model T5-3B

# %%
local_output_dir="/opt/home/bo_ling/dolly_training/eats_receipt_gcp_t5_v3"
#model, tokenizer = load_model_tokenizer_for_generate(local_output_dir)
import torch
tokenizer = AutoTokenizer.from_pretrained(local_output_dir)
device = "cuda:2" if torch.cuda.is_available() else "cpu"
model = T5ForConditionalGeneration.from_pretrained(local_output_dir, trust_remote_code=True).to(device)
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.

# %%
def generate_transcipt_response(
    input_text: str,
    model: PreTrainedModel,
    tokenizer: PreTrainedTokenizer,
    PAD_TOKEN = "<pad>",
    EOS_TOKEN = "</s>",
    do_sample: bool = True,
    max_new_tokens: int = 768,
    top_p: float = 0.85,
    top_k: int = 0,
    **kwargs,
) -> str:
    input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to(device)

    end_key_token_id = tokenizer.encode(EOS_TOKEN)[0]

    gen_tokens = model.generate(
        input_ids,
        pad_token_id=tokenizer.pad_token_id,
        # Ensure generation stops once it generates "### End"
        eos_token_id=end_key_token_id,
        do_sample=do_sample,
        max_new_tokens=max_new_tokens,
        top_p=top_p,
        top_k=top_k,
        **kwargs,
    )[0].cpu()

    decoded = tokenizer.decode(gen_tokens).strip(PAD_TOKEN).strip(EOS_TOKEN).strip()

    return decoded

# %% [markdown]
# # Print some sample output for human to read

# %%
count = 0
for d in test_data['test']:
    input_text= d["input_text"]
    generated = generate_transcipt_response(input_text, model, tokenizer)
    expected = d['output_text']
    print("="*100)
    print("="*100)
    print("\nINPUT:")
    print(input_text)
    print("\nGENERATED:")
    print(generated)
    print("\nEXPECTED:")
    print(expected)
    count += 1
    if count > 50:
        break
# Out:
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 199 Dir BRIAN CONLEY
# 1219 Broadway Avenue
# BOISE ID 83706
# (208)336-5278
# GROCERY
# LACROIX 8PK
# 4.59 B
# 2 QTY SIG WATER
# 5.98 B
# Regular Price
# 7.58
# You Save
# 1.60-
# BARILLA PASTA
# 1.99 B
# Regular Price
# 2.49
# You Save
# 0.50-
# REFRIG/FROZEN
# 5.29 B
# CREAM CHEESE
# TAX
# 1.07
# TAX EXEMPTION
# 1.07-
# **** BALANCE
# 17.85
# Credit Purchase 02/26/23 14:26
# CARD # ************000
# REF: 882607465070 AUTH: 00736188
# PAYMENT AMOUNT
# 17.85
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# 17.85
# Visa
# 0.00
# CHANGE
# TOTAL NUMBER OF ITEMS SOLD = 5
# TAX EXEMPT ID: ***
# ***000
# 02/26/23 14:26 199 1 102 8729
# YOUR CASHIER TODAY WAS JACK
# YOUR SAVINGS
# 2.10
# Store Savings
# 2.10
# Total
# 11%
# Total Savings Value
# 00019900101022302261426
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00019900101022302261426; total_price: 17.85; total_tax: 1.07
#
# EXPECTED:
# receipt_number: 00019900101022302261426; total_price: 17.85; total_tax: 1.07
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'INO
# SAFEWAY S
# Store 1513 Dir Shayne Adams
# Main: (410) 319-8591 Rx: (410) 319-8620
# 4401 Harford Road
# BALTIMORE MD 21214
# GROC NONEDIBLE
# AJAX DISH ORANGE.
# 3.99 T
# Regular Price
# 4.99
# Member Savings
# 1.00-
# 2 QTY SCOTT BATH 11.58 T
# Regular Price
# 11.98
# Member Savings
# 0.40-
# GEN MERCHANDISE
# PULL-UPS LEARNING . 11.99
# Regular Price
# 12.99
# Member Savings 1.00-
# MISCELLANEOUS
# MR
# DSPSBL BAG CHARGE
# 0.05
# TAX
# 0.93
# **** BALANCE
# 28.54
# Credit Purchase 02/28/23 10:37
# CARD # ************000
# REF: 313752421630 AUTH: 00498001
# PAYMENT AMOUNT
# 28.54
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 28.54
# CHANGE
# 0.00
# 6% SALES TAX
# 0.93
# TOTAL NUMBER OF ITEMS SOLD =
# 4
# 02/28/23 10:37 1513 175 17
# 8821
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 2.40
# Total
# 2.40
# Total Savings Value
# 8%
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# ||||
# 00151317500172302281037
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00151317500172302281037; total_price: 28.54; total_tax: 0.93
#
# EXPECTED:
# receipt_number: 00151317500172302281037; total_price: 28.54; total_tax: 0.93
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 1469 Dir Tawnya Johnson
# Main:(410) 869-8220
# 5660 Baltimore National Pike
# BALTIMORE MD 21228
# GROCERY
# TOAST CRUNCH
# 5.99 S
# OCN SPRY CRAN
# 3.49 S
# Regular Price
# 3.99
# Member Savings
# 0.50-
# KELLOGGS FROSTED
# 6.99 S
# BANG ENERGY DRINK
# 3.29 B
# GROCERY
# 3.99 S
# GEN MERCHANDISE
# CARESS BODY WASH
# 6.29 T
# TAX
# 0.57
# **** BALANCE
# 30.61
# Credit Purchase 02/27/23 10:56
# CARD # ************000
# REF: 815648479270 AUTH: 00998415
# PAYMENT AMOUNT
# 30.61
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 30.61
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 6
# 02/27/23 10:56 1469 53 36
# 8853
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 0.50
# 0.50
# Total
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# 00146905300362302271056
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00146905300362302271056; total_price: 30.61; total_tax: 0.57
#
# EXPECTED:
# receipt_number: 00146905300362302271056; total_price: 30.61; total_tax: 0.57
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 132 Dir Jeannifer Pickett
# Main:(562) 988-8785
# 101 E Willow Blvd
# LONG BEACH CA 90806
# GROCERY
# BARCEL TAKIS FUEGO
# 4.49 S
# BOOM CHICKA CRN PO
# 3.99 S
# REFRIG/FROZEN
# FL NTRL JUICE ORIG
# 6.99 S
# Regular Price
# 7.99
# Sale Savings
# 1.00-
# GEN MERCHANDISE
# REUSABLE BAG
# 0.10
# PRODUCE
# SUJA IMMUNITY
# 3.49 S
# CRV PROD
# SNGL NTX
# 0.05 S
# HAPPY POWERED SHOT
# 3.49 S
# CRV PROD SNGL NTX
# 0.05 S
# VIVE ORGA SHOT WEL
# 3.49 S
# CRV PROD SNGL NTX
# 0.05 S
# VIVE ORG GINGER
# 3.49 S
# CRV PROD SNGL NTX
# 0.05 S
# TAX
# 0.00
# **** BALANCE
# 29.73
# Credit Purchase
# 02/24/23 19:05
# CARD # ********
# ***000
# REF: 380555471520 AUTH: 00878602
# PAYMENT AMOUNT
# 29.73
# AL
# AID A0000000031010
# TVR 0000000000
# TSI 0000
# Visa
# 29.73
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 12
# 02/24/23 19:06 132 6 305 1701
# POINTS EARNED TODAY
# Base Points 29
# Total 29
# Points Towards Next Reward 29 of 100
# YOUR CASHIER TODAY WAS BRIANA
# YOUR SAVINGS
# Store Savings
# 1.00
# Total
# 1.00
# 00013200603052302241906
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# $5
# OFF
# Sign up with Albertsons for U and receive
# $5 Off your next purchase of $25 or more*
# Click on deals, click on for U and claim
# this exclusive offer.'?
#
# GENERATED:
# receipt_number: 00013200603052302241906; total_price: 29.73; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00013200603052302241906; total_price: 29.73; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Store 2042 Dir Jeff Michlitsch
# Main:(602) 955-6455 Rx:(602) 957-4265
# 3132 E Camelback Rd.
# PHOENIX AZ 85016
# ERY CE
# GROCERY
# NBC PREM SALTINE OD
# 4.99 S
# REFRIG/FROZEN
# 2 QTY LUC VIT D_
# 7.58 S
# TAX
# 0.00
# **** BALANCE
# 12.57
# Credit Purchase 02/27/23 17:35
# CARD # ************000
# REF: 453522438680 AUTH: 00141924
# PAYMENT AMOUNT
# 12.57
# AL VISA CREDIT
# AID A0000000031010
# 12UM
# TVR 8000008000
# TSI 6800
# Visa
# 12.57
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 02/27/23 17:35 2042 177 195
# 8823
# *
# SAFEWAY S
# __________............----------------
# POINTS EARNED TODAY
# Base Points 12
# Total 12
# Points Towards Next Reward 9 of 100
# REWARDS AVAILABLE
# 6
# YOUR CASHIER TODAY WAS SELF
# mas 00204217701952302271735/ww
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 2HAT31 877-276-9637 or Safeway.com/foru
# OFA132'?
#
# GENERATED:
# receipt_number: 00204217701952302271735; total_price: 12.57; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00204217701952302271735; total_price: 12.57; total_tax: 0.0
# Token indices sequence length is longer than the specified maximum sequence length for this model (596 > 512). Running this sequence through the model will result in indexing errors
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 359 Dir Kevin Thill
# Main: (818) 894-6415
# 9022 Balboa Blvd
# NORTHRIDGE CA 91325
# GROCERY
# SUNCHIPS SALSA
# 3.99 S
# Regular Price
# 4.19
# Sale Savings
# 0.20-
# CHEETOS CRUNCHY
# 3.99 S
# Regular Price
# 6.59
# Sale Savings
# 2.60-
# SMARTFOOD POPCORN
# 3.99 S
# Regular Price
# 6.59-
# Sale Savings
# 2.60-
# 1 QTY
# REESES MILK CHOC
# 1.67 S
# Regular Price
# 2.50
# Sale Savings
# 0.83-0
# NBC OREO MLK CKY
# 4.99 S
# Regular Price
# 5.79
# Sale Savings
# 0.80-
# GEN MERCHANDISE
# 2 QTY REUSABLE B
# 0.20
# PRODUCE
# RASPBERRIES RED
# 3.99 S
# STRAWBERRIES 1LB
# 3.99 S
# Regular Price
# 4.99
# Sale Savings
# 1.00-
# BLUEBERRIES 6OZ
# 3.50 S
# Regular Price
# 3.99
# Sale Savings
# 0.49-
# TAX
# 0.00
# TRX EXEMPTION
# 0.00
# **** BALANCE
# 30.31
# Credit Purchase 02/24/23 22:25
# CARD # ************000
# REF: 732555465990 AUTH: 00607330
# PAYMENT AMOUNT
# 30.31
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 30.31
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 10
# TAX EXEMPT ID: Not Available
# 02/24/23 22:25 359 4 185 4992
# YOUR CASHIER TODAY WAS Bruce
# YOUR SAVINGS
# 8.52
# Store Savings
# 8.52
# Total
# Total Savings Value
# 22%
# 00035900401852302242225
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00035900401852302242225; total_price: 30.31; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00035900401852302242225; total_price: 30.31; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 2783 Dir Mark DeLeon
# Main: (619) 660-9717 Rx: (619) 670-7880
# 2899 Jamacha Rd
# EL CAJON CA 92019
# GROCERY
# P/FARM COKIE
# 4.79 S
# Regular Price
# 4.99
# Sale Savings
# 0.20-
# GLDFSH COLORS CRCK 2.99 S
# Regular Price 3.29
# Sale Savings
# 0.30-
# TWIZZLERS PNP CHRY 2.99 S
# GROC NONEDIBLE
# 930900 VALUE CRNR BLEACH
# 3.99 T
# VALUE CORNER TOWEL
# 5.99 T
# Regular Price
# 7.99
# Sale Savings
# 2.00-
# REFRIG/FROZEN
# KERNS AQUAS FRESCA
# 3.99 S
# Regular Price
# 1.49
# 12 S
# Sale Savings
# 0.50-
# 26514 goiqqoT I
# GEN MERCHANDISE
# 619 MR CLEAN GLV MRC
# 4.99 T
# 3 QTY REUSABLE B
# 0.30
# VAR
# SWIFFER SWEEPER
# 9.99 T
# SWFFRWETOWFREF 105
# 7.99 T
# FANTASTIK CLEANER 1
# 4.49 T
# gyna die
# SEAFOOD B
# 2 QTY WFB TARTAR
# 5.00 S
# Regular Price inst5.983
# Sale Savings
# 0.98-
# 2 QTY GORTONS FS
# 10.99 S
# Regular Price
# 21.98
# Sale Savings
# 10.99-
# 22 VOA
# TAX
# 2.90
# **** BALANCE
# 71.39
# Credit Purchase 02/26/23 17:52
# CARD # ************000
# REF: 465240480380 AUTH: 00153718
# 2939 23 JA2 9012
# PAYMENT AMOUNT
# 71.39
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 680000 AM 0
# 3MU23RA TIMBU2 OT
# Visa 08 A
# 71.39
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 17
# 02/26/23 17:52 2783 54 118
# 8854
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 14.97
# Total
# 14.97
# Total Savings Value
# 18%
# 00278305401182302261752
# m2
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# #ss19 goiqqoT POS
# nii saison 20:32
# sbo2 113
# Hosesda A VRA'?
#
# GENERATED:
# receipt_number: 00278305401182302261752; total_price: 71.39; total_tax: 2.9
#
# EXPECTED:
# receipt_number: 00278305401182302261752; total_price: 71.39; total_tax: 2.9
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'LUA
# wesome
# new,
# Albertsons
# Store 4152 Dir Kim Maris
# Main:(940) 383-2391 Rx: (940) 383-1696
# 2321 W University Dr
# DENTON TX 76201
# GROCERY
# 5.99 S
# LAWRYS SEASND SALT
# 3.99 S
# 2 QTY KLLGGS POP
# Regular Price
# 7.98
# 3.99-
# You Save
# 2.69 S
# OPN NAT PICKLES
# REFRIG/FROZEN
# 4.99 S
# ORE IDA EX CRISPY
# 0.00
# TAX
# 17.66
# **** BALANCE
# Credit Purchase 02/26/23 17:50
# CARD # ************000
# REF: 295002412200 AUTH: 00686367
# PAYMENT AMOUNT
# 17.66
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 17.66
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 5
# 02/26/23 17:50 4152 4 228 6567
# YOUR CASHIER TODAY WAS Robin
# YOUR SAVINGS
# Store Savings
# 3.99
# Total
# 3.99
# Total Savings Value
# 18%
# ||||||
# 00415200402282302261750
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00415200402282302261750; total_price: 17.66; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00415200402282302261750; total_price: 17.66; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 4191 Dir Dicky Lewis
# Main: (940) 321-4540 Rx: (940) 321-4361
# 4351 Fm 2181
# Corinth TX 76210
# GROCERY
# 2 QTY BODYARMOR
# 3.58 B
# REFRIG/FROZEN
# SIMPLY JUICE
# 3.99 S
# Regular Price
# 4.29
# You Save
# 0.30-
# GEN MERCHANDISE
# PROBIOTIC SPPLMNT
# 17.99
# SIG MIGRAIN RELIEF
# 4.49 Q
# PRODUCE
# 3 QTY
# BANANAS GREEN
# 0.75 S
# TAX
# 0.30
# **** BALANCE
# 31.10
# Credit Purchase 02/26/23 13:21
# CARD # ************000
# REF: 492145464290 AUTH: 00121106
# PAYMENT AMOUNT
# 31.10
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 31.10
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 8
# 02/26/23 13:21 4191 54 76
# 8854
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 0.30
# Total
# 0.30
# 00419105400762302261321
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00419105400762302261321; total_price: 31.1; total_tax: 0.3
#
# EXPECTED:
# receipt_number: 00419105400762302261321; total_price: 31.1; total_tax: 0.3
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'MEWA
# :
# net 0.01 0z./0.28 ge
# PENCIL
# Wear
# 24H
# Up to
# PROVED
# TE
# SAFEWAY S
# Store 1192 Dir Dave Buck
# Main: (925) 356-2710 Rx: (925) 356-2712
# 4309 Clayton Rd
# Concord CA 94521
# GROCERY
# NONG SHIM NEOGURI
# 7.99 S
# 2 QTY TOP RAMEN AC
# 12.98 S
# NUTELLA HZLNT CHOCAC
# 8.99 S
# REFRIG/FROZEN
# LUC EGGS LARGE A
# 4.89 S
# MEAT
# EYE OF RND STK THN
# 8.45 S
# PK CHOPS ASTD
# 7.34 S
# DELI
# 2 QTY SC SOUP JA
# 13.98 S
# MISCELLANEOUS
# MR
# 3 QTY RCYCBLE BA
# 0.30
# TAX
# 0.00
# **** BALANCE
# 64.92
# Credit Purchase 02/27/23 22:21
# CARD # ************000
# REF: 682104402870 AUTH: 00875925
# PAYMENT AMOUNT
# 64.92
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 64.92
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 9
# 02/27/23 22:21 1192 94 131
# 8894
# Join the Safeway Club today.
# Membership is Free and Instant
# YOUR CASHIER TODAY WAS SELF
# 00119209401312302272221
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00119209401312302272221; total_price: 64.92; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00119209401312302272221; total_price: 64.92; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# 30
# Store 1276 Dir Ryan Rose
# Main: (202) 723-5644 Rx: (202) 723-5612
# 6500 Piney Branch Rd N.W.
# WASHINGTON DC 20012
# GROCERY
# 2 QTY MNGO NCTR
# 5.98 B
# MISCELLANEOUS
# MR
# DSPSBL BAG CHARGE
# 0.05
# TAX
# 0.48
# **** BALANCE
# 6.51
# Credit Purchase 02/27/23 14:42
# CARD # ******
# ****000
# REF: 114203436060 AUTH: 00827276
# PAYMENT AMOUNT
# 6.51
# AL
# AID A0000000031010
# TVR 0000000000
# TSI 0000
# Visa
# 6.51
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 2
# 02/27/23 14:42 1276 53 67
# 8853
# YOUR CASHIER TODAY WAS SELF
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# |||||||
# 00127605300672302271442
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru
# V
# COUPON LINH'?
#
# GENERATED:
# receipt_number: 00127605300672302271442; total_price: 6.51; total_tax: 0.48
#
# EXPECTED:
# receipt_number: 00127605300672302271442; total_price: 6.51; total_tax: 0.48
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# EU
# Store 1627 Dir Alex Argetsinger
# Main:(503) 772-4440 Rx: (503) 772-4445
# 3940 S.E. Powell
# PORTLAND OR 97202
# GROCERY
# CHEEZ IT CRCKR
# 7.99 S
# ROLD GOLD TWISTS
# 3.79 S
# Regular Price
# 3.99
# Member Savings
# 0.20-
# 2 QTY CHEETOS CR
# 11.38 S
# Regular Price
# 13.18
# Member Savings
# 1.80-2
# HSHY ASTD CHOC PAR. 12.99 S
# Regular Price
# 15.49
# Member Savings
# 2.50-
# OREO COOKIES DBL
# 6.29 S
# Regular Price
# 6.79
# Member Savings 0.50-
# TAKIS FUEGO FIESTA. 6.49 S
# Regular Price
# 6.99
# Member Savings 0.50-
# MISCELLANEOUS
# MR
# 2 QTY RCYCBLE BA
# 0.20
# M04003 ACT
# 0.2025
# SUR
# 0.00
# **** BALANCE
# 49.13
# Credit Purchase 02/27/23 18:12
# CARD # *******
# **000
# REF: 221241402500 AUTH: 00647810
# Ami
# PAYMENT AMOUNT
# 49.13
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# HO T
# Visa
# 49.13
# 910 10 5
# 10m 110 06
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 7
# 02/27/23 18:12 1627 51 131
# 8851
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 5.50
# Total
# 5.50
# Total Savings Value
# 10%
# 20
# 00162705101312302271812
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00162705101312302271812; total_price: 49.13; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00162705101312302271812; total_price: 49.13; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'to 291195010
# SAFEWAY S
# Store 985 Dir Rosemarie
# Main:(415) 665-4565 Rx: (415) 665-8456
# 2350 Noriega Street
# SAN FRANCISCO CA 94122
# GROCERY
# SMARTFOOD POPCORN
# 4.49 S
# Regular Price
# 4.99
# Member Savings
# 0.50-
# 6 QTY NBC OREO M. 29.94 S
# Regular Price
# 40.74
# Member Savings 10.80-
# GEN MERCHANDISE
# Uw
# 2 QTY CLIF BAR P
# 15.98 S
# Regular Price
# 19.98
# Member Savings
# 4.00-
# CLIF ENERGY BAR
# 7.99 S
# Regular Price
# 9.99
# Member Savings
# 2.00-
# 2 QTY LIF ENERGY. 15.98 S
# Regular Price
# 19.98
# Member Savings
# 4.00-
# www.albertsonscompanies.com/nofi for loyalty program
# 2 QTY CLIF BARS
# 15.98 S
# 2VLEMVA 382 ENY LOB VDAEBLIZING DECOR
# Regular Price
# 19.98
# 1001
# Member Savings 4.00-
# MISCELLANEOUS
# 0.50
# MR
# 2 QTY RCYCBLE BA
# ire your privacy rights, contact us at
# terial terms and related privacy disclosures.
# Albertsons Companies' Notice of Financial incentive (NOFI)
# Signing up for one of our loyalty programs? Take a minute to review
# Learn more at www.albertsonscompanies.com/privacy
# and responsibly to improve your experience with us.
# When you share your personal information, we use it carefully
# (877) 251-6552.
# TAX
# 0.00
# TAX EXEMPTION
# 0.00
# TION
# 90.86
# **** BALANCE
# Credit Purchase 02/27/23 16:53
# CARD # ************000
# REF:
# 065329496040 AUTH: 00801431
# 90.86
# PAYMENT
# AMOUNT
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI
# 6800
# 90.86
# Visa
# 0.00
# CHANGE
# 14
# TOTAL
# NUMBER OF ITEMS SOLD =
# ACH payment may be debited electronically
# Along with the Service Fee, each unpaid check or
# returned item or, if lower, the maximum allowed by law.
# to a Service Fee of $25, and $35 for each additional
# returned unpaid by your financial institution, is subject
# Each check or electronic fund transfer (ACH) payment, if
# POLICY FOR RETURNED CHECKS, ACH, & OTHER EFT PAYMENTS
# your bank account
# TAX EXEMPT ID: Not Available
# 02/27/23 16:53 985 4 77 6457
# YOUR CASHIER TODAY WAS Liezel
# YOUR SAVINGS
# 26.30
# Member Savings
# 25.30
# Total
# 22%
# Total Savings Value
# ||||||||
# 00098500400772302271653
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00098500400772302271653; total_price: 90.86; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00098500400772302271653; total_price: 90.86; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 2747 Dir Chuck Ungos
# Main: (808) 733-2600 Rx: (808) 733-2606
# 888 Kapahulu Avenue
# HONOLULU HI 96816
# GROCERY
# 3.34 B
# 2 QTY SIG CORN W
# Regular Price
# 4.58
# Member Savings
# 1.24-
# 1.99 B
# SIG TOMATO PASTE
# 2 QTY HNTS PETIT
# 8.58 B
# Regular Price
# 10.98
# Member Savings
# 2.40-
# 2 QTY CHILI SEAS
# 6.98 B
# HINODE CALROSE RIC
# 10.79 B
# 2 QTY O ORG BEAN
# 4.38 B
# MEAT
# 80% LEAN GR BEEF
# 7.83 B
# Regular Price
# 10.07
# Member Savings 2.24-
# MISCELLANEOUS
# 2 QTY RCYCBLE BA
# 0.30 T
# MR
# TAX
# 2.08
# **** BALANCE
# 46.27
# Credit Purchase 02/27/23 19:35
# CARD # **** ****000
# REF: 063535487100 AUTH: 00957356
# PAYMENT AMOUNT
# 46.27
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 46.27
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 11
# 02/27/23 19:35 2747 177 59
# 8823
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 5.88
# Total
# 5.88
# Total Savings Value
# 12%
# 00274717700592302271935
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru
# GARDA
# 2352
#
# irendezert
# Febe
# SOP:'?
#
# GENERATED:
# receipt_number: 00274717700592302271935; total_price: 46.27; total_tax: 2.08
#
# EXPECTED:
# receipt_number: 00274717700592302271935; total_price: 46.27; total_tax: 2.08
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 3021 Dir Kelli Khoury
# Main: (702) 562-1745 Rx: (702) 562-1832
# 10140 W. Flamingo Road
# Las Vegas NV 89147
# GROCERY
# CHEEZ-IT CRACKERS
# 4.99 S
# RUFFLES POT CHPS
# 2.50 S
# Regular Price
# 5.99
# Sale Savings
# 3.49-
# RUFFLES POT CHPS
# 2.50 S
# Regular Price
# 5.99
# Sale Savings
# 3.49-
# TWIZZLERS TWISTS
# 3.49 S
# HANDI SNACKS
# 4.99 S
# FIJI ARTSIAN WATER
# 2.50 S
# Regular Price
# 2.79
# Sale Savings
# 0.29-
# FIJI WATER
# 12.99 S
# Regular Price
# 13.99
# Sale Savings
# 1.00-
# 4 QTY NISSIN BOW
# 6.00 S
# Regular Price
# 7.96
# Sale Savings
# 1.96-
# TAX
# 0.00
# **** BALANCE
# 39.96
# Credit Purchase 02/26/23 18:50
# CARD # ************000
# REF: 435050424770 AUTH: 00895466
# PAYMENT AMOUNT
# 39.96
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 39.96
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 11
# 02/26/23 18:50 3021 3 87 4417
# YOUR CASHIER TODAY WAS Vanessa
# YOUR SAVINGS
# Store Savings
# 10.23
# Total
# 10.23
# Total Savings Value
# 20%
# 00302100300872302261850
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00302100300872302261850; total_price: 39.96; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00302100300872302261850; total_price: 39.96; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 252 Dir Bill Robinson
# Main: (509) 627-4714 Rx: (509) 627-5133
# 690 Gage Blvd
# Richland WA 99352
# GROCERY
# JUANITAS TORTILLA
# 4.99 S
# MISSION FLR TRTLA
# 4.79 S
# REFRIG/FROZEN
# FRIGO CHSE SHRD
# 6.19 S
# PRODUCE
# TF CAESAR SALAD KT
# 4.49 S
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.08 T
# TAX
# 0.01
# **** BALANCE
# 20.55
# Credit Purchase 02/27/23 18:19
# CARD # ************000
# REF: 931938497220 AUTH: 00701993
# PAYMENT AMOUNT
# 20.55
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 20.55
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 4
# 02/27/23 18:19 252 52 154
# 8852
# ****
# NOW HIRING!
# See Store Director or visit
# www.Safeway.com/Careers to apply
# **
# COUL
# V
# YOUR CASHIER TODAY WAS SELF
# ||||
# 00025205201542302271819
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru
# 5.'?
#
# GENERATED:
# receipt_number: 00025205201542302271819; total_price: 20.55; total_tax: 0.01
#
# EXPECTED:
# receipt_number: 00025205201542302271819; total_price: 20.55; total_tax: 0.01
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Ready
# Albertsons
# Store 4713 Dir Michael Rogers
# Main: (760) 735-5131 Rx: (760) 735-5884
# 1509 E. Valley Pkwy
# ESCONDIDO CA 92027
# GEN MERCHANDISE
# AVEENO LOTION PUMP
# 10.99 T
# TAX
# 0.85
# **** BALANCE
# 11.84
# Credit Purchase 02/27/23 21:18
# CARD # ************000
# REF: 461832494390 AUTH: 00954690
# PAYMENT AMOUNT
# 11.84
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# 11.84
# Visa
# 0.00
# CHANGE
# TOTAL NUMBER OF ITEMS SOLD =
# 1
# 02/27/23 21:18 4713 54 154
# 8854
# YOUR CASHIER TODAY WAS SELF
# 00471305401542302272118
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
#
# COUPON
# LLN'?
#
# GENERATED:
# receipt_number: 00471305401542302272118; total_price: 11.84; total_tax: 0.85
#
# EXPECTED:
# receipt_number: 00471305401542302272118; total_price: 11.84; total_tax: 0.85
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from '110-
# SAFEWAY.
# Store 1439 Dir Team 1439
# Main:(408) 481-3300 Rx (408) 481-3302
# 785 East El Camino Real
# SUNNYVALE CA 94807
# GROCERY
# BC FUDGE BRWNI MIX
# 3.49 S
# BC CHOC CHIP COOKI
# 4.49 S
# AJUOY J.
# MOD
# DELI JOYAS
# BH MEAT CHS TRAY
# 15.99 S
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.10
# TAX
# 0.00
# **** BALANCE
# 24.07
# Credit Purchase 02/27/23 21:36
# CARD # ************000
# MEMO
# REF: 993648415370 AUTH: 00177704
# PAYMENT AMOUNT
# 24.07
# UST
# AL VISA CREDIT
# AID A0000000031010 us
# TVR 8000008000
# TSI 6800
# Visa
# 24.07
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 3
# 02/27/23 21:36 1439 53 178
# 8853
# YOUR CASHIER TODAY WAS SELF
# 00143905301782302272136
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru moz
# 53'?
#
# GENERATED:
# receipt_number: 00143905301782302272136; total_price: 24.07; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00143905301782302272136; total_price: 24.07; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 1579 Dir Amanda Gayle
# Main: (301) 916-8584 Rx: (301) 916-8587
# 19718 Germantown Road
# GERMANTOWN MD 20874
# GROCERY
# 2 QTY 00 GARBANZ
# 3.58 S
# 4 QTY O ORG CHIC
# 8.00 S
# Regular Price
# 10.00
# Member Savings 2.00-
# SEAFOOD
# 2 QTY GORTONS PR
# 10.99 S
# Regular Price
# 21.98
# Member Savings
# 10.99-
# PRODUCE
# AVOCADOS HASS
# 4.99 S
# TAX
# 0.00
# **** BALANCE
# 27.56
# Credit Purchase 02/27/23 19:05
# CARD # ******* ***000
# REF: 360543496340 AUTH: 00964640
# PAYMENT AMOUNT
# 27.56
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 27.56
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 9
# 02/27/23 19:05 1579 94 162
# 8894
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 12.99
# Total
# 12.99
# Total Savings Value
# 32%
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# 00157909401622302271905
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru
# O'?
#
# GENERATED:
# receipt_number: 00157909401622302271905; total_price: 27.56; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00157909401622302271905; total_price: 27.56; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 561 Dir Michael Salinas
# Main: (626) 446-1416 Rx: (626) 446-1902
# 298 E. Live Oak Ave.
# ARCADIA CA 91006
# GROCERY
# 2 QTY REIGN RAZZ
# 5.98 B
# CRV SFTDK SNGL TAX
# 0.10 B
# GEN MERCHANDISE
# DOVE BODY AND FACE
# 7.99 T
# Regular Price
# 9.99
# Sale Savings
# 2.00-
# 1.44
# TAX
# 15.51
# **** BALANCE
# Credit Purchase 02/27/23 11:28
# CARD # ************000
# REF: 712802419730 AUTH: 00400802
# ee
# an the shelf or advertised price
# k verification.
# 15.51
# price.
# PAYMENT AMOUNT
# d on every chec
# AL VISA CREDIT
# established che
# AID A0000000031010
# 25658.4 Business and Profe
# TVR 8000008000
# Icoholic beverages in violation
# TSI 6800
# alcoholic beverage to any cu
# ars; (2) The customer looks c
# 33
# BBY EBEE BVBEB VBEBL2012 ] D B VDAEBLIZING CV 800-4-483
# 15.51
# Visa
# ours of 2 a.m. and 6 a.m. or
# is to drink the alcoholic beve
# 0.00
# er violation of the California
# CHANGE
# TOTAL NUMBER OF ITEMS SOLD =
# 5
# en approved th
# 02/27/23 11:28 561 1 142 7803
# be charged. (
# d must have a match/rela
# ent, if returned
# xpired.
# additional re
# YOUR CASHIER TODAY WAS Andrew G
# sales tax on the full price
# paid check o
# California Redemption Va
# a cash credit or payout
# YOUR SAVINGS
# ernet coupons for free
# 2.00
# limited to a max value
# Store Savings
# 2.00
# st be capable of scann
# Total
# issued accor
# 12%
# > refuse any coupons a
# Total Savings Value
# ssued. Refund
# s are not accepted at -
# sh refunds for
# Acceptance Policy
# fant formula
# 00056100101422302271128
# Thank you for shopping Albertsons!
# licy
# For ALBERTSONS FOR U questions call
# out of an advertised i
# 877-276-9637 or Albertsons.com/foru
# ns.com/foru
# ds cannot be
# d price. Rain checks
# din one transaction
# BbY EBEE BVBEK
# T
# 910M 10 282 to 22dasons'?
#
# GENERATED:
# receipt_number: 00056100101422302271128; total_price: 15.51; total_tax: 1.44
#
# EXPECTED:
# receipt_number: 00056100101422302271128; total_price: 15.51; total_tax: 1.44
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'ESTA-02-18
# Hertson
# Albertsons
# Store 1262 Dir AJ Flores
# Main:(817) 354-0622 Rx: (817) 354-0991
# 1300 Airport Fwy
# BEDFORD TX 76022
# GROCERY
# NBC RITZ CRACKERS
# 3.99 S
# Regular Price
# 4.49
# You Save
# 0.50-M
# 2 QTY NABISCO 80
# 10.98 S
# REFRIG/FROZEN
# LUC PPR JACK TRAY
# 4.49 S
# BAKED GOODS
# LIL DEBBIE
# 2.59 S
# NAT OWN WHAT HONEY
# 4.29 S
# (S0S0.4.4.1
# MEAT
# HF BLACK FOREST HA 4.49 S
# Regular Price
# 5.99
# You Save
# 1.50-
# WRIGHTS BACON
# 11.49 S
# Regular Price
# 11.99
# You Save
# 0.50-
# O PRODUCE 4XG
# 1.46 lb @ $1.99 /lb
# WT
# HOTHOUSE TOMATOES
# 2.91 S
# Regular Price
# 3.64
# You Save
# 0.73-
# TAX
# TAXO
# 0.00
# **** BALANCE
# 45.23
# 203392010
# MA
# Credit Purchase 02/26/23 10:47
# CARD # ******* ****000
# REF: 444744402640 AUTH: 00567368
# PAYMENT AMOUNT
# 45.23
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 45.23
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 02/26/23 10:47 1262 52 26
# 8852
# W
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# 3.23 ch
# Store Savings
# 3.23 enha
# Total
# way
# Total Savings Value
# 7%
# genom
# 281163
# 00126205200262302261047
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# 1E3'?
#
# GENERATED:
# receipt_number: 00126205200262302261047; total_price: 45.23; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00126205200262302261047; total_price: 45.23; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 590 Dir Chad Onchi
# Main:(503) 591-7557 Rx: (503) 591-0997
# 7500 E Main St
# Hillsboro OR 97123
# GROCERY
# GRANOLA BAR
# 4.99 S
# REFRIG/FROZEN
# 2 QTY LUC WHOLE
# 6.78 S
# HOLD
# LUC YOGURT STRWBRY
# 2.49 S
# TUNE/SCF
# E
# Regular Price
# 2.79
# A
# *
# Media B
# You Save
# 0.30-
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.10
# FYTYYTE
#
# TAX
# 0.00
# crazy
# **** BALANCE
# 14.36
# Browse
# DISC:
# On
# Zac Gi
# Credit Purchase 02/28/23 07:33
# CARD # ************000 bom100bni of of
# REF: 953328421740 AUTH: 00854941
# crazy
# Change Device
# MOUNT 374
# PAYMENT AMOUNT
# USB
# 1/1
# 14.36
# RADIO
# AL VISA CREDIT
# CLAW DROGE
# (2
# AID A0000000031010
# VORO 723807
# TVR 8000008000
# *
# TSI 6800
# iPhone
# 02:37
# 00:0
# Visa
# 14.36
#
# HONE
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 02/28/23 07:33 590 51
# 3
# 8851
#
# x
# 11
# K
# YOUR CASHIER TODAY WAS SELF
# Repeat
# APPS
# Shuffle
# YOUR SAVINGS
# Store Savings
# 0.30
# Total
# 0.30
# |||||
# 00059005100032302280733
# Thank you for shopping Albertsons!
# OUT TEMP
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# 36F
# 3
# PM
# ANYARA
# MAX
# ON/
# * < >$
# A/C
# A/C
# AUTO
# OFF
# 86
# MODE
# FRONT
# SYNC
# 81
# GAME
# OREGON
# Na
# Chap Stick
# NOLUA
# 50016 NO
# OBLIN 18 A
# TUR
# LOTTERY
# NOUTAN BOL
# POWER BALL
# -----
# YOUR CASHT
# Patric
# 02/27/23 15
# TOTAL NUME
# TSI 6
# TVR
# for a chance t
# AID
# and other exc 09
# AL
# no Ta'?
#
# GENERATED:
# receipt_number: 00059005100032302280733; total_price: 14.36; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00059005100032302280733; total_price: 14.36; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 1948 Dir Bruce Franz
# Main:(480) 830-5132 Rx: (480) 830-5185
# 441 N. Val Vista
# Mesa AZ 85213
# GROCERY
# 1.25 S
# CHILI MIX
# Regular Price
# 1.99
# Sale Savings
# 0.74-
# KAYTEE GRMT RABBIT
# 6.99 T
# REFRIG/FROZEN
# DAISY SOUR CREAM
# 1.99 S
# Regular Price
# 2.49
# Sale Savings
# 0.50-
# BAKED GOODS
# SIG BUNS HAMBURGER 2.29 S
# Regular Price
# 2.49
# Sale Savings
# 0.20-
# MEAT
# OPN NAT GRND BEEF
# 7.99 S
# PRODUCE
# SIG SNACKNG TOMATO
# 4.99 S
# 0.43 lb @ $0.59 /lb
# BANANAS YELLOW
# WTE
# 0.25 S
# CELERY MEDIUM
# 1.99 S
# YELLOW ONIONS
# 0.69 S
# NTR SWT TOMATOES
# 5.00 S
# TAX
# 0.58
# **** BALANCE
# 34.01
# Credit Purchase 02/25/23 11:26
# CARD # ************000
# REF: 392656401250 AUTH: 00742417
# 34.01
# PAYMENT AMOUNT
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# 34.01
# Visa
# 0.00
# CHANGE
# TOTAL NUMBER OF ITEMS SOLD =
# 10
# 02/25/23 11:27 1948 94 81
# 8894
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# 1.44
# Store Savings
# Total
# 1.44
# 00194809400812302251127
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 277-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00194809400812302251127; total_price: 34.01; total_tax: 0.58
#
# EXPECTED:
# receipt_number: 00194809400812302251127; total_price: 34.01; total_tax: 0.58
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 2606 Dir Dave Papalias
# Main: (415) 633-1001 Rx: (415) 633-1020
# 298 King St.
# SAN FRANCISCO CA 94107
# GEN MERCHANDISE
# SWIFFER SWEEPER
# 6.99 T
# SWIFFER WET HVY AC
# 12.99 T
# GILLETTE
# 3.49 T
# G-U-M FLSSRS EZTHRAC
# 3.49 T
# 2.33
# TAX
# 29.29
# **** BALANCE
# Credit Purchase 02/27/23 19:42
# CARD # ************000
# REF 824208461040 AUTH: 00150581
# 29.29
# PAYMENT AMOUNT
# AL
# AID A0000000031010
# TVR 0000000000
# TSI 0000
# Visa
# 29.29
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 4
# 02/27/23 19:42 2606 96 204
# 8896
# Join the Safeway Club today.
# Membership is Free and Instant
# YOUR CASHIER TODAY WAS SELF
# 00260609602042302271942
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00260609602042302271942; total_price: 29.29; total_tax: 2.33
#
# EXPECTED:
# receipt_number: 00260609602042302271942; total_price: 29.29; total_tax: 2.33
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 3989 Dir Matt Clarke
# Main:(480) 396-9282 Rx:(480) 396-3838
# 2727 N Power Rd
# Mesa AZ 85215
# GROCERY
# CKTL SAUCE
# 4.49 S
# KRAFT SAUCEWORKS S
# 2.99 S
# Regular Price
# 3.99
# Sale Savings
# 1.00-
# TAX
# 0.00
# **** BALANCE
# 7.48
# Credit Purchase 02/27/23 17:32
# CARD # ************000
# REF: 663226466450 AUTH: 00563322
# PAYMENT AMOUNT
# 7.48
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 7.48
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD = 2
# 02/27/23 17:32 3989 2 272 6283
# YOUR CASHIER TODAY WAS Andrew
# YOUR SAVINGS
# Store Savings
# 1.00
# Total
# 1.00
# Total Savings Value
# 12%
# ||||||
# 00398900202722302271732
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# 229'?
#
# GENERATED:
# receipt_number: 00398900202722302271732; total_price: 7.48; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00398900202722302271732; total_price: 7.48; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'AAlbertsons
# Store 745 Dir Tamera Gibson
# Main:(619) 237-1247 Rx: (619) 237-9127
# 655 14th Street
# SAN DIEGO CA 92101
# GEN MERCHANDISE
# SIG TURBO PLUNGER 7.99 T
# Regular Price
# 9.99
# Sale Savings
# 2.00-
# 0.62
# TAX
# **** BALANCE
# 8.61
# Credit Purchase 02/27/23 20:47
# CARD # ************000
# REF: 434741450770 AUTH: 00828042
# PAYMENT AMOUNT
# 8.61
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 8.61
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 1
# 02/27/23 20:47 745 93 161
# 8893
# POINTS EARNED TODAY
# Base Points 7
# Total 7
# Points Towards Next Reward 7 of 100
# YOUR CASHIER TODAY WAS SELF
# 3
# YOUR SAVINGS
# Store Savings
# 2.00
# Total
# 2.00
# Total Savings Value
# 20%
# 00074509301612302272047
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# County of San Diego,
# Department of Agriculture, Weights and Measures at:
# 1-888-TRUE-SCAN (1-888-878-3722) or www.sdcawm.org
# Overd arged? Notify our department
# NOW
# with the Tiels Us Now App'?
#
# GENERATED:
# receipt_number: 00074509301612302272047; total_price: 8.61; total_tax: 0.62
#
# EXPECTED:
# receipt_number: 00074509301612302272047; total_price: 8.61; total_tax: 0.62
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 1596 Dir Scott Preston
# Main:(410) 451-4750 Rx: (410) 451-4775
# 2644 Chapel Lake Drive www
# GAMBRILLS MD 21054
# GROCERY
# 2 QTY KRAFT MAC
# 9.58 S
# Regular Price
# 10.58
# Member Savings
# 1.00-
# COCA COLA CLASSIC
# 3.39 B
# SLAP YA MAMA SSNNG
# 4.99 S
# REFRIG/FROZEN
# TURKEY HILL SWEET
# 2.99 S
# 3.79
# 101
# Regular Price
# LOS VDABULISHO CVIT RED-S
# Member Savings 0.80-
# Hoar
# 2 QTY MRS T PIER
# 7.98 S
# NATHANS FAMOUS FRN.
# 5.99 S
# Regular Price
# 6.49
# Member Savings 0.50-
# TAX
# 3200H
# 0.20
# **** BALANCE
# 23 35.12
# Credit Purchase 02/27/23 17:02
# CARD # ************000
# REF: 120208419660 AUTH: 00743486
# fronto
# TUO YANES
# shmark
# PAYMENT AMOUNT
# 35.12
# 15138
# AL VISA CREDIT
# AID A0000000031010
# MBEGUT
# TVR 8000008000
# D
# TSI 6800
# GROOD
# Visa 803 190U
# 35.12
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 8
# 02/27/23 17:02 1596 51 60
# 8851
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 2.30
# Total
# 2.30
# 20
# Total Savings Value
# 6%
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# orov
# JUTA
# 2
# 11043
# EYLEMVA 129
# |||||||||
# 00159605100602302271702
# Thank
# for shopping Safel'?
#
# GENERATED:
# receipt_number: 00159605100602302271702; total_price: 35.12; total_tax: 0.2
#
# EXPECTED:
# receipt_number: 00159605100602302271702; total_price: 35.12; total_tax: 0.2
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 601 Dir
# Main:(626) 963-5358 Rx: (626) 963-5368
# 133 West Route 66
# GLENDORA CA 91740
# REFRIG/FROZEN
# KRAFT PARMSN
# 5.99 S
# CHINES
# Regular Price
# 6.99
# Sale Savings
# 1.00-
# LUC CREAM CHEESE
# 3.99 S
# Regular Price
# 4.49
# Sale Savings
# 0.50-
# LUC CHESE SWISS
# 3.79 S
# Regular Price
# 3.99
# Albertsons
# Sale Savings
# 0.20-
# fasten securely.
# LUC WHIPPED CREAM
# 3.49 S
# child in car seat
# ALWAYS buck
# GEN MERCHANDISE
# 2 QTY REUSABLE B
# 0.20
# BAKED GOODS
# S SELECT BREAD
# 3.49 S
# ONLY use cart seat for C
# MEAT
# ALL NATURAL FULLY
# 6.99 S
# Regular Price
# 9.99
# Sale Savings
# 3.00-
# LOF DELI SHAVED
# 2.99 S
# Regular Price
# 3.99
# Sale Savings
# 1.00-
# O
# PRODUCE
# SIG RED ONIONS
# 2.99 S
# DELI
# FRIED CKN 8CT HOT
# 9.99 T
# to ride in basket.
# TAX
# 1.02
# **** BALANCE
# 44.93
# Credit Purchase 02/25/23 18:18
# ges 6.48 months and 15-35 lbs
# Do NOT allow child
# CARD # ************000
# REF: 861855445830 AUTH: 00656531
# SHOPPING CART THEFT LAW
# IF CART IS FOUND OFF STORF PREMISES CALL TOLL FREE FOR CART PICK-UP (800) 252-4613
# ANY REMOVAL MUSI BE BY WRITTEN PERMISSION OF STORE MANAGEMENT.
# CALIFORNIA STATELANIB & P CODE 22435 INEVADA STATE LAW. IN. R. S. 205.860)
# THIS SHOPPING CART IS A VIOLATION OF THE FOLLOWING STATE LAW
# UNAUTHORIZED XEMOVAL FROM PREMISES OR POSSESSION OF
# PAYMENT AMOUNT
# 44.93
# own
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# carrier or car seat.
# Textub
# Visa
# 44.93
# For Shopping
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 11
# 02/25/23 18:18 601 1 331 3598
# YOUR CASHIER TODAY WAS Mckaylen
# YOUR SAVINGS
# Store Savings
# 5.70
# Total
# 5.70
# Total Savings Value
# 11%
# 00060100103312302251818
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00060100103312302251818; total_price: 44.93; total_tax: 1.02
#
# EXPECTED:
# receipt_number: 00060100103312302251818; total_price: 44.93; total_tax: 1.02
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 2509 Dir Todd Broom
# Main: (949) 492-1755 Rx: (949) 492-9448
# 804 Avenida Pico
# SAN CLEMENTE CA 92673
# GROCERY
# 2 QTY SIG DISTIL
# 1.98 S
# CRV SFTDK SNGL NTX
# 0.20 S
# SIG WTR PUR DRNKNG
# 3.99 S
# CRV SFTDK 24PK NTX
# 1.20 S
# 2 QTY PRINGLES C
# 4.98 S
# Regular Price
# 6.98
# Sale Savings
# 2.00-
# 2 QTY COCA COLA
# 4.58 B
# CRV SFTDK SNGL TAX
# 0.10 B
# Regular Price
# 5.58
# Sale Savings
# 1.00-
# MONSTER ENERGY
# 2.99 B
# CRV SFTDK SNGL TAX
# 0.05 B
# MONSTER ENERGY
# 7.99 B
# CRV SFTDK 4 PK TAX
# 0.20 B
# Regular Price
# 9.29
# Sale Savings
# 1.30-
# GEN MERCHANDISE
# REUSABLE BAG
# 0.10
# TAX
# 1.23
# **** BALANCE
# 29.59
# Credit Purchase 02/25/23 13:25
# CARD # ************000
# REF: 372551472290 AUTH: 00297597
# PAYMENT AMOUNT
# 29.59
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 29.59
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 17
# 02/25/23 13:25 2509 51 49
# 8851
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 4.30
# Total
# 4.30
# Total Savings Value
# 13%
# 00250905100492302251325
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00250905100492302251325; total_price: 29.59; total_tax: 1.23
#
# EXPECTED:
# receipt_number: 00250905100492302251325; total_price: 29.59; total_tax: 1.23
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'AIMEE
# SAFEWAY S
# Store 1620 Dir Janice Hill
# Main: (301) 670-1626 Rx: (301) 670-1631
# 20211 Goshen Road
# GAITHERSBURG MD 20879
# GROCERY
# TOP RAMEN BEEF
# 0.75 S
# Regular Price
# 0.79
# Member Savings
# 0.04-
# NISSAN TOP RAMEN 3.50 S
# Regular Price
# 3.79
# Member Savings
# 0.29-
# NISSIN NOODLE BOWL.
# 1.50 S
# Regular Price
# 1.69
# Member Savings 0.19-
# IBC ROOT BEER
# 5.69 B
# MIKES MIG SOUP VGT
# 2.99 S
# REFRIG/FROZEN
# TURKEY HILL VAN
# 7.19 S
# BUBBIES ICE CREAM
# 6.49 B
# MISCELLANEOUS
# MR 2 QTY DSPSBL BAG
# 0.10
# TAX
# 0.73
# **** BALANCE
# 28.94
# Credit Purchase 02/28/23 08:58
# CARD # ************000
# REF: 645836434040 AUTH: 00022247
# PAYMENT AMOUNT
# 28.94
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 5800
# 28.94
# Visa
# 0.00
# CHANGE
# 0.73
# 6% SALES TAX
# TOTAL NUMBER OF ITEMS SOLD =
# 7
# 8822
# 02/28/23 08:58 1620 176
# 4
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# 0.52
# Member Savings
# 0.52
# Total
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# 00162017600042302280858
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00162017600042302280858; total_price: 28.94; total_tax: 0.73
#
# EXPECTED:
# receipt_number: 00162017600042302280858; total_price: 28.94; total_tax: 0.73
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Magell
# (714) 300-6775
# Name: Micheel laws.
# Registration #1978
# Date Agent #31787
# @
# Albertsons
# Store 4131 Dir Rickie Farley
# Main: (323) 295-1919 Rx: (323) 295-3330
# 3901 Crenshaw Blvd
# LOS ANGELES CA 90008
# GROCERY
# SPRITE SODA
# 2.29 B
# CRV SFTDK SNGL TAX
# 0.05 B
# ARROWHEAD WATER
# 5.99 S
# CRV SFTDK 24PK NTX
# 1.20 S
# Regular Price
# 6.99
# Sale Savings
# 1.00-
# 2 QTY O ORG COCO
# 6.98 S
# Regular Price
# 7.98
# Sale Savings
# 1.00-
# C20 PURE CCNT WTR
# 2.29 S
# CRV SFTDK SNGL NTX
# 0.05 S
# Regular Price
# 2.99
# Sale Savings
# 0.70-
# LINDT EXCELLENCE 7 2.99 S
# Regular Price
# 3.99
# Sale Savings
# 1.00-
# GEN MERCHANDISE
# REUSABLE BAG
# 0.10
# BAKED GOODS
# FRENCH BREAD
# 2.49 S
# TAX
# 0.22
# **** BALANCE
# 24.65
# Credit Purchase 02/25/23 22:01
# CARD # ************000
# REF: 410149434870 AUTH: 00237107
# PAYMENT AMOUNT
# 24.65
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 24.65
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 11
# 02/25/23 22:01 4131 52 237
# 8852
# POINTS EARNED TODAY
# Base Points 23
# Total 23
# Points Towards Next Reward 23 of 100
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 3.70
# Total
# 3.70
# 13%
# Total Savings Value
# 00413105202372302252201
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# NG
# g v
# $5
# 6
# OFF
# 20
# ds redemption
# more*
# Albertsons for U
# sons.com/foru-guest.html
# mit 1 per household. Restricts
# alid only for new Albertsons for U
# subjec
# Jbe'?
#
# GENERATED:
# receipt_number: 00413105202372302252201; total_price: 24.65; total_tax: 0.22
#
# EXPECTED:
# receipt_number: 00413105202372302252201; total_price: 24.65; total_tax: 0.22
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'erely
# Health
# hen you si
# SAFEWAY S
# Store 879 Dir Ian Krupnick
# Main: (719) 593-8805
# 4405 Centennial Blvd
# Colorado Springs CO 80919
# cep
# GROCERY
# Pay
# 4.49 S
# SMARTFOOD FLAMIN
# Regular Price
# 4.99
# Member Savings
# 0.50-
# SMARTFOOD POPCORN
# 4.49 S
# Regular Price
# 4.99
# Member Savings
# 0.50-
# and the Android Logo are trademarks of Goo
# of Apple Inc., registered in the U.S. and oth
# arks of Samsung Electronics Co., Ltd. App
# msung Samsung Pay, Knox, Galaxy Son
# TOSTITOS_TORTILLA
# 4.99 S
# Regular Price
# 5.59
# Member Savings
# 0.60-
# 4.79 S
# NBC OREO COOKIES
# 4.99
# Regular Price
# 0.20-
# Member Savings
# 3 QTY COCA COLA
# 25.47 B
# REFRIG/FROZEN
# 5.99 S
# FAST FRIES
# Regular Price
# 6.99
# H
# Member Savings 1.00-
# GEN MERCHANDISE
# SAFEWA
# 1239
# PAMP EASYUP 4T5T
# 10.99
# MEAT
# 47
# 6.48 S
# LEAN GRND BF
# Valued Customer!
# 3.59 B
# 010M LUNCHABLES FUN PK
# Regular Price
# 3.99
# Member Savings 0.40-
# pleased with everything you purcha
# DELI
# OJMWO
# 8.99 T
# CKN WHOLE ROASTED
# MISCELLANEOUS
# 0.50
# 5 QTY DSPSBL BAG
# 1.77
# TAX
# 1.77-
# TAX EXEMPTION
# 80.77
# **** BALANCE
# TA_A__
# nager on duty for assistance.
# ment to your satisfaction. If for son
# providing fresh quality products ev
# with your shopping experience,
# is not as you expected it to be, re
# MR
# out Payment Options
# Credit Purchase 02/27/23 17:02
# rds
# CARD # ************000
# ...
# 6.99
# You Save
# 0.50-
# BAKED GOODS
# FRENCH BREAD
# 1.99 B
# 6.92
# TAX
# **** BALANCE
# 122.13
# Credit Purchase 02/25/23 10:11
# CARD # *******
# ***000
# REF: 981139429840 AUTH: 00434985 WW
# PAYMENT AMOUNT
# 122.13
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# PAAUHD 387
# 122.13
# 8 30 32/
# Visa mw
# VTREBI2013 1BS LIV LOB VDAEBLI2IMG Cyrr Do
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 23
# 02/25/23 10:11 182 2 50 9978
# YOUR CASHIER TODAY WAS Rebecca
# YOUR SAVINGS
# 15.66
# Store Savings
# 15.66
# Total
# 12%
# Total Savings Value
# ||||
# 00018200200502302251011
# Thank you for shopping Albertsons! m
# For ALBERTSONS FOR U questions call 3
# 877-276-9637 or Albertsons.com/foru
# moozebensqms-zonst'?
#
# GENERATED:
# receipt_number: 00018200200502302251011; total_price: 122.13; total_tax: 6.92
#
# EXPECTED:
# receipt_number: 00018200200502302251011; total_price: 122.13; total_tax: 6.92
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'GURA
# Store 3129 Dir Ron Sousa
# Main: (661) 827-0394
# 3500 Panama Lane
# BAKERSFIELD CA 93313
# snack is
# print
# s or Com
# GROCERY
# 52-4477
# GMILLS CINN TST
# 6.49
# S
# DORITOS TORTILLA
# 5.59 S
# olay.com
# to 4:30pm CT
# Regular Price
# 6.59
# Sale Savings
# 1.00-
# KELLOGGS APPLE
# 4.00 S
# Regular Price
# 6.99
# Sale Savings
# 2.99-
# NBC CHIPS AHOY CHU 4.99 S
# NBC RITZ FRESH
# 4.99 S
# Regular Price
# 5.99
# Sale Savings
# 1.00-
# REFRIG/FROZEN
# 2 QTY SIG LUCERN
# 9.98 S
# KNUDSEN COTTAGE
# 4.49 S
# Regular Price
# 5.99
# Sale Savings
# 1.50-
# BAKED GOODS
# 2 QTY ENTENM BRW
# 8.00 S
# Regular Price
# 11.58
# Sale Savings
# 3.58-
# Flavor
# MISCELLANEOUS
# MR
# Albertsons
# 5 QTY RCYCBLE BA
# 0.50
# TAX
# 0.00
# **** BALANCE
# 49.03
# Credit Purchase 02/24/23 21:02
# CARD # ************000
# REF: 750213413990 AUTH: 00548648
# PAYMENT AMOUNT
# 49.03
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 49.03
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 10
# 02/24/23 21:02 3129 51 131
# 8851
# 2
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 10.07
# Total
# 10.07
# Total Savings Value
# 17%
# ||||||
# 00312905101312302242102
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00312905101312302242102; total_price: 49.03; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00312905101312302242102; total_price: 49.03; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 4129 Dir Gerald Degelia
# Main:(972) 270-2406 Rx: (972) 270-4448
# 2828 Motley Drive
# Mesquite TX 75150
# GROCERY
# KRAFT SAUCEWORKS S
# 2.99 S
# SLD DRESSING
# 3.49 S
# Regular Price 4.49
# You Save
# 1.00-
# PRODUCE
# 15 QTY
# BANANAS GREEN
# 1.25 S
# TAX
# 0.00
# **** BALANCE
# 7.73
# Credit Purchase 02/26/23 17:20
# CARD # ************000
# REF: 942019429200 AUTH: 00847130
# PAYMENT AMOUNT
# 7.73
# Al. VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 7.73
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 7
# 02/26/23 17:20 4129 52 108
# 8852
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 1.00
# Total
# 1.00
# Total Savings Value
# 11%
# 00412905201082302261720
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# 52'?
#
# GENERATED:
# receipt_number: 00412905201082302261720; total_price: 7.73; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00412905201082302261720; total_price: 7.73; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 275 Dir BRANDEN NISHIKAWA
# Main: (808) 664-7725 Rx: (808) 664-7730
# 94-809 Lumiaina Street
# WAIPAHU HI 96797
# BAKED GOODS
# CAKE BIRTHDAY
# 6.49 B
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.15 T
# TAX
# 0.31
# **** BALANCE
# 6.95
# Credit Purchase 02/27/23 13:41
# CARD # ************000
# REF: 704105400790 AUTH: 00913631
# PAYMENT AMOUNT
# 6.95
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 6.95
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 1
# 02/27/23 13:41 275 6 406 1211
# YOUR CASHIER TODAY WAS Sky
# 00027500604062302271341
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00027500604062302271341; total_price: 6.95; total_tax: 0.31
#
# EXPECTED:
# receipt_number: 00027500604062302271341; total_price: 6.95; total_tax: 0.31
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'ap
# Store 1165 Dir Jim Gonzales
# Main: (714) 992-6099 Rx: (714) 992-6739
# 2291 West Malvern Ave
# FULLERTON CA 92833
# REFRIG/FROZEN
# NESTLE TOLLHOUSE
# 8.99 S
# Regular Price
# 9.99
# Sale Savings
# 1.00-
# TILLAMOOK MINT CHO
# 6.99 S
# GEN MERCHANDISE
# REUSABLE BAG
# 0.10
# BAKED GOODS
# PETITE CHOC CAKE
# 9.99 S
# Regular Price 10.99
# Sale Savings
# 1.00-
# TAX
# 0.00
# **** BALANCE
# 26.07
# Credit Purchase
# 02/26/23 20:47
# CARD # ************000
# REF: 964718488570 AUTH: 00578710
# PAYMENT AMOUNT
# 26.07
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 26.07
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 02/26/23 20:47 1165 1 448 7966
# REWARDS AVAILABLE
# 2
# DO
# POINTS EARNED TODAY
# Base Points 25
# Total 25
# Points Towards Next Reward 31 of 100
# YOUR CASHIER TODAY WAS Amanda
# YOUR SAVINGS
# Store Savings
# 2.00
# Total
# 2.00
# Total Savings Value
# 7%
# 00116500104482302262047
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# t
# Albertsons
# P+6'?
#
# GENERATED:
# receipt_number: 00116500104482302262047; total_price: 26.07; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00116500104482302262047; total_price: 26.07; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'AAlbertsons
# Store 387 Dir Richard Sage
# Main:(323) 660-0687 Rx: (323) 662-5105
# 2035 Hillhurst Ave.
# LOS ANGELES CA 90027
# GROCERY
# SKIPY EX CHUNKY
# 3.99 S
# GEN MERCHANDISE
# REUSABLE BAG
# 0.10
# BAKED GOODS
# DAVES KILLER BREAD
# 7.49 S
# TAX
# 0.00
# **** BALANCE
# 11.58
# Credit Purchase 02/26/23 12:46
# CARD # ************000
# P
# REF: 394632497010 AUTH: 00684519
# PAYMENT AMOUNT
# 11.58
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 11.58
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 3
# 02/26/23 12:46 387 54 89
# 8854
# POINTS EARNED TODAY
# Base Points 11
# Total 11
# Points Towards Next Reward 11 of 100
# YOUR CASHIER TODAY WAS SELF
# 00038705400892302261246
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# N'?
#
# GENERATED:
# receipt_number: 00038705400892302261246; total_price: 11.58; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00038705400892302261246; total_price: 11.58; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'AAlbertsons
# Store 1948 Dir Bruce Franz
# Main:(480) 830-5132 Rx: (480) 830-5185
# 441 N. Val Vista
# Mesa AZ 85213
# GROCERY
# SIG COFFEE CANULAR
# 10.99 S
# TOSTITOS TORTILLA
# 5.29 S
# Regular Price
# 5.99
# Sale Savings
# 0.70-
# REFRIG/FROZEN
# B&J C/CHIP CKY DG
# 4.99 S
# Regular Price
# 6.49
# Sale Savings
# 1.50-
# TAX
# 0.00
# **** BALANCE
# 21.27
# Credit Purchase 02/27/23 19:14
# CARD # ************000
# REF: 201443455310 AUTH: 00415137
# PAYMENT AMOUNT
# 21.27
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 21.27
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 3
# 02/27/23 19:14 1948 53 151
# 8853
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Store Savings
# 2.20
# Total
# 2.20
# Total Savings Value
# 9%
# 00194805301512302271914
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00194805301512302271914; total_price: 21.27; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00194805301512302271914; total_price: 21.27; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 4004 Dir Steve St. Pierre
# Main: (702) 869-1474 Rx: (702) 869-9503
# 4055 S Durango Dr
# Las Vegas NV 89147
# ertsons PO
# GROCERY
# Ale of cigarettes or any other tobacco
# SWISS MISS HOT COC
# GCO Sales
# 7.99 S
# fortunate enough to look under the age
# Auct to persons under the age of 21. If you
# 13 QTY CRYSTAL GE
# 23.27 S
# 50, please be prepared to present a valid
# TAX
# 0.00
# **** BALANCE
# 31.26
# ure ID.
# We Accept
# VISA
# Credit Purchase 02/27/23 15:03
# SAMSOND
# DISCOVER MasterCard
# pay
# CARD # ************000
# REF: 340323499430 AUTH: 00218348
# G Pay Pay
# 11
# & ATM/Debit Ca
# les
# State laws re
# lo
# of age to pur
# PAYMENT AMOUNT
# 31.26
# ve the right
# sale of alcoh
# AL VISA CREDIT
# NOTIC Pursuant to LVMC 10
# AID A0000000031010
# is unlad for a person to dri
# TVR 8000008000
# an opeontainer of alcohol
# TSI 6800
# SAVE
# e premises, the
# 1,000 feet of t
# Visa
# 31.26
# or up
# Receipt
# WH
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD = 14
# 02/27/23 15:03 4004 1 175 0024
# WITH THE F
# LICY
# pons against one item in a transaction,
# on stacking does not allowstomer to rede
# . If the
# MS ON THE COU
# POINTS EARNED TODAY
# recei'
# Base Points 31
# have beer
# n will be honored. Coupon sang policies t
# Limit
# Total 31
# ernet prin
# pable of
# acci
# paper and electronic coupo
# an ind
# ele
# internet printed coupons mu
# We will not accept free produ
# Points Towards Next Reward 31 of 100
# have serial numbers and mus
# Expired coupons will not be ab
# YOUR CASHIER TODAY WAS sarit
# For complete Coupon Acceptanco bylicy
# 00400400101752302271503
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru
# $5
# C6'?
#
# GENERATED:
# receipt_number: 00400400101752302271503; total_price: 31.26; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00400400101752302271503; total_price: 31.26; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'Albertsons
# Store 4187 Dir Raymond Maddox
# Main: (972) 285-0226 Rx: (972) 285-1352
# 19
# 1500 S Beltline Rd
# MESQUITE TX 75149
# 3759 f*
# GROCERY
# SMARTFOOD POPCORN
# 4.99 S
# OCN SPRY CNRBRY
# 3.49 B
# Regular Price
# 3.79
# You Save
# 0.30-
# CRAN-GRAPE
# 3.49 B
# Regular Price
# 3.79
# You Save
# 0.30-
# GATORADE G ZERO
# 7.29 B
# TAX
# 1.18
# **** BALANCE
# 20.44
# Credit Purchase 02/26/23 14:01
# CARD # ************000
# REF: 280113447460 AUTH: 00131450
# PAYMENT AMOUNT
# 20.44
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 20.44
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 4
# 02/26/23 14:01 4187 2 63 6330
# YOUR CASHIER TODAY WAS Deanna
# YOUR SAVINGS
# Store Savings
# 0.60
# Total
# 0.60
# 00418700200632302261401
# Thank you for shopping Albertsons!
# For ALBERTSONS FOR U questions call
# 877-276-9637 or Albertsons.com/foru'?
#
# GENERATED:
# receipt_number: 00418700200632302261401; total_price: 20.44; total_tax: 1.18
#
# EXPECTED:
# receipt_number: 00418700200632302261401; total_price: 20.44; total_tax: 1.18
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 2242 Dir Robert Morton
# Main: (916) 456-0852 Rx: (916) 456-3421
# 1025 Alhambra Blvd.
# SACRAMENTO CA 94816
# REFRIG/FROZEN
# LUC CHESE SRP CHEDAC
# 4.49 S
# LUC HALF & HALF
# 1.99 S
# SIG BROC FLORETS
# 2.79 S
# PRODUCE
# SIG SHRED CARROTS
# 2.99 S
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.10
# TAX
# 0.00
# **** BALANCE
# 12.36
# Credit Purchase 02/27/23 14:54
# CARD # ************000
# REF: 155448422040 AUTH: 00560675
# PAYMENT AMOUNT
# 12.36
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 12.36
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 4
# 02/27/23 14:54 2242 53 122
# 8853
# Join the Safeway Club today.
# Membership is Free and Instant
# YOUR CASHIER TODAY WAS SELF
# 00224205301222302271454
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00224205301222302271454; total_price: 12.36; total_tax: 0.0
#
# EXPECTED:
# receipt_number: 00224205301222302271454; total_price: 12.36; total_tax: 0.0
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY S
# Store 3250 Dir Nicole Bently
# Main: (571) 312-0029 Rx:(571) 312-1506
# 3526 King Street
# ALEXANDRIA VA 22302
# GROCERY
# 2 QTY S SEL SPRI
# 9.98 B
# REFRIG/FROZEN
# CHOBANI COFF CRMR
# 4.50 B
# Regular Price
# 5.99
# Member Savings
# 1.49-
# PRODUCE
# 2 QTY
# SIG SALAD ROMAINE
# 5.00 B
# MEDITERRANEAN CHOP
# 4.29 B
# FRSH EXP SWT KALE.
# 2.50 B
# Regular Price
# 4.29
# Member Savings
# 1.79-
# 1.29 lb @ $0.79 /lb
# WT
# ORG BANANAS
# 1.02 B
# MISCELLANEOUS
# MR
# 2 QTY DSPSBL BAG
# 0.10
# TAX
# 0.27
# **** BALANCE
# 27.66
# Credit Purchase 02/27/23 16:07
# CARD # ************000
# REF: 830749473820 AUTH: 00513440
# PAYMENT AMOUNT
# 27.66
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# COUPON
# 27.66
# Visa
# 0.00
# CHANGE
# TOTAL NUMBER OF ITEMS SOLD =
# 8
# 8894
# 02/27/23 16:07 3250 94 113
# DAIMO Ceri (GO) SA 1235
# YOUR CASHIER TODAY WAS SELF
# UU YOUR SAVINGS
# 2938
# 3.28
# Member Savings
# 3.28
# Total
# 11%
# Total Savings Value
# HOW WAS YOUR SHOPPING EXPERIENCE?
# WE VALUE YOUR FEEDBACK!
# SCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY
# EYLEMYA 9520 036 LOW VRAESLUG
# 100
# 00325009401132302271607
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00325009401132302271607; total_price: 27.66; total_tax: 0.27
#
# EXPECTED:
# receipt_number: 00325009401132302271607; total_price: 27.66; total_tax: 0.27
# ====================================================================================================
# ====================================================================================================
#
# INPUT:
# Extract 23-digit receipt_number, total_price, and total_tax from 'SAFEWAY
# Store 1484 Dir Brian Knoblauch
# Main: (425) 258-3552 Rx: (425) 252-1911
# 4128 Rucker Ave
# Everett WA 98201
# GROCERY
# NERDS CLUSTERS
# 5.29 S
# 3 QTY BENS ORIGI
# 9.87 S
# Regular Price
# 10.47
# Member Savings
# 0.60-
# 3 QTY OPN NAT DO
# 5.97 T
# 2 QTY 100 GRAND
# 3.58 S
# REFRIG/FROZEN
# MARIE CLNDR MEAL
# 6.99 S
# Regular Price
# 7.79
# Member Savings
# 0.80-
# MISCELLANEOUS
# MR
# RCYCBLE BAG CHARGE
# 0.08 T
# TAX
# 0.60
# **** BALANCE
# 32.38
# Credit Purchase 02/27/23 19:38
# CARD # ************000
# REF: 093813414990 AUTH: 00509168
# PAYMENT AMOUNT
# 32.38
# AL VISA CREDIT
# AID A0000000031010
# TVR 8000008000
# TSI 6800
# Visa
# 32.38
# CHANGE
# 0.00
# TOTAL NUMBER OF ITEMS SOLD =
# 10
# 02/27/23 19:38 1484 176 184
# 8822
# ****
# NOW HIRING!
# See Store Director or visit
# www.Safeway.com/Careers to apply
# ***
# ****
# YOUR CASHIER TODAY WAS SELF
# YOUR SAVINGS
# Member Savings
# 1.40
# Total
# 1.40
# ||||||
# 00148417601842302271938
# Thank you for shopping Safeway!
# For SAFEWAY FOR U questions call
# 877-276-9637 or Safeway.com/foru'?
#
# GENERATED:
# receipt_number: 00148417601842302271938; total_price: 32.38; total_tax: 0.6
#
# EXPECTED:
# receipt_number: 00148417601842302271938; total_price: 32.38; total_tax: 0.6

# %%
def str_to_json(js, do_print_exception=False):
    res = {}
    for ss in js.lower().split(";"):
        try:
            k, v = ss.split(":")
            if k.strip() in ["total_price", "total_tax"]:
                res[k.strip()] = float(v.strip())
            else:
                res[k.strip()] = v.strip()
        except:
            if do_print_exception:
                print(js)
    return res
str_to_json("receipt_number: 00400505302182302271921; total_price: 10.98; total_tax: 0.0")
# Out:
# {'receipt_number': '00400505302182302271921',
#  'total_price': 10.98,
#  'total_tax': 0.0}

# %% [markdown]
# #  Compute accuracy leftout test dataset

# %%
statistics = {"receipt_number": 0, "total_price": 0, "total_tax": 0}
count  = 0
for d in test_data['test']:
    input_text= d["input_text"]
    generated = str_to_json(generate_transcipt_response(input_text, model, tokenizer), True)
    expected = str_to_json(d['output_text'])
    for k, v in expected.items():
        if k in generated and v == generated[k]:
            statistics[k] += 1

# %%
for k, v in statistics.items():
    print(f"=========Correctly extracted {v} {k} among {len(test_data['test'])}, accuracy is {v/len(test_data['test'])} ")
# Out:
# =========Correctly extracted 349 receipt_number among 350, accuracy is 0.9971428571428571
# =========Correctly extracted 348 total_price among 350, accuracy is 0.9942857142857143
# =========Correctly extracted 349 total_tax among 350, accuracy is 0.9971428571428571

# %%
statistics = {"receipt_number": 0, "total_price": 0, "total_tax": 0}
count  = 0
for d in test_data['test']:
    input_text= d["input_text"]
    
    expected = str_to_json(d['output_text'])
    if expected["receipt_number"] == "00175817601672302272019":
        print(generate_transcipt_response(input_text, model, tokenizer), d)
# Out:
# receipt_number: 00175817601672302272019; total_price: 11.47; total_tax: 0.0 {'input_text': "Extract 23-digit receipt_number, total_price, and total_tax from 'an\nSAFEWAYS\nStore 1758 Dir Dee Frances\nMain (410) 256-3021 Rx (410) 256-6423\n9645 Belair Road\nPerry Hall MD 21128\nare\nREFRIG/FROZEN\n2.99 S\nGOLD PEAK\nRegular Price\n3.19\nMember Savings\n0.20-\nBAKED GOODS\n3.99 S\nBREAD\nPRODUCE\n2n\nSIG FARMS HER SL\n1.99 S\n1 QTY\nMED HASS AVOCADOS\n2,50 S\nROOS\n0.00\nTAX\n**** BALANCE\n11.47\nCredit Purchase 02/27/23 20:19\nLOB VDAEBLIZIN cvr\nCARD # ************000\nREF: 431911468260 AUTH: 00783373\nPAYMENT AMOUNT\n11.47\nAL VISA CREDIT\nAID A0000000031010\nTVR 800000800048\n9\nTSI 6800\nVisa 130 ase 11.47\nCHANGE\n0.00\nTOTAL NUMBER OF ITEMS SOLD =\n4\n02/27/23 20:19 1758 176 167\n8822\nYOUR CASHIER TODAY WAS SELF\nYOUR SAVINGS\nMember Savings\n0.20\nTotal\n0.20\nHOW WAS YOUR SHOPPING EXPERIENCE?\nWE VALUE YOUR FEEDBACK!\nSCAN THE QR CODE BELOW FOR A TWO MINUTE SURVEY\na bore\nGATYBM SCUOY\n00175817601672302272019\nThank you for shopping Safeway!\nFor SAFEWAY FOR U questions call\n877-276-9637 or Safeway.com/foru'?", 'output_text': 'receipt_number: 00175817601672302272019; total_price: 11.47; total_tax: 0.0'}
